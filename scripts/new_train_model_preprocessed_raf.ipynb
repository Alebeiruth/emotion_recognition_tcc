# %%
"""
=============================================================================
TREINAMENTO BASELINE - DATASET PRÉ-PROCESSADO (SEM AUGMENTATION)
=============================================================================
Pipeline de treinamento para dataset processado:
1. Carrega dataset RAF-DB
2. NÃO aplica augmentation (dados já processados)
3. Treina múltiplos modelos: ResNet50, EfficientNet-B0, EfficientViT
4. Early stopping para evitar overfitting
5. Monitoramento de tempo e memória
6. Salva métricas completas + matriz normalizada + modelo .pth

ESTRATÉGIA BASELINE:
- Dataset: Processado e não balanceado
- Modelos: 3 arquiteturas diferentes
- Métricas: Completas (Acc, F1, Precision, Recall, por classe)
- Monitoramento: Tempo e memória (CPU/GPU)
=============================================================================
"""

import os
import cv2
import gc
import json
import time
import psutil
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.models as models

from sklearn.metrics import (
    accuracy_score, 
    f1_score, 
    precision_score, 
    recall_score,
    classification_report,
    confusion_matrix,
    precision_recall_fscore_support
)
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
# =============================================================================
# CONFIGURAÇÕES
# =============================================================================

# Dispositivo
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# Caminhos
DATASET_PATH = r"../data/processed/RAF-DB"
RESULTS_PATH = r"../results/baseline/RAF-DB"
MODELS_PATH = os.path.join(RESULTS_PATH, "models")
METRICS_PATH = os.path.join(RESULTS_PATH, "metrics")
PLOTS_PATH = os.path.join(RESULTS_PATH, "plots")

# Criação de diretórios
os.makedirs(MODELS_PATH, exist_ok=True)
os.makedirs(METRICS_PATH, exist_ok=True)
os.makedirs(PLOTS_PATH, exist_ok=True)

# Parâmetros de Treinamento
EPOCHS = 100
LR = 1e-4
BATCH_SIZE = 64
NUM_WORKERS = 4

# Early Stopping
EARLY_STOP_PATIENCE = 15
EARLY_STOP_MIN_DELTA = 0.001

# Pesos para métricas combinadas
F1_WEIGHT = 0.6
ACC_WEIGHT = 0.4

# Mapeamento de classes
EMOTION_LABELS = {
    'Raiva': 0, 'Nojo': 1, 'Medo': 2, 'Felicidade': 3,
    'Neutro': 4, 'Tristeza': 5, 'Surpresa': 6
}

# Seed para reprodutibilidade
SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed(SEED)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

print("="*80)
print("TREINAMENTO BASELINE - DATASET PRÉ-PROCESSADO (SEM AUGMENTATION)")
print("="*80)
print(f"Dispositivo: {DEVICE}")
print(f"Dataset: {DATASET_PATH}")
print(f"Épocas máximas: {EPOCHS}")
print(f"Batch size: {BATCH_SIZE}")
print(f"Early Stopping: Patience={EARLY_STOP_PATIENCE}")
print(f"Augmentation: NÃO (dados já processados)")
print("="*80)
# Out:
# ================================================================================
# TREINAMENTO BASELINE - DATASET PRÉ-PROCESSADO (SEM AUGMENTATION)
# ================================================================================
# Dispositivo: cuda
# Dataset: ../data/processed/RAF-DB
# Épocas máximas: 100
# Batch size: 64
# Early Stopping: Patience=15
# Augmentation: NÃO (dados já processados)
# ================================================================================

# %%
# CLASSE DE MONITORAMENTO
class ResourceMonitor:
    def __init__(self, model_name):
        self.model_name = model_name
        self.start_time = None
        self.end_time = None
        self.peak_memory_mb = 0
        self.initial_memory_mb = 0
        self.training_time = 0
        self.process = psutil.Process()
        self.peak_gpu_memory_mb = 0
        self.initial_gpu_memory_mb = 0
        self.epoch_times = []

    def record_epoch_time(self, seconds: float):
        # guarda o tempo de época
        self.epoch_times.append(float(seconds))

    def get_epoch_time_stats(self):
        import numpy as np
        if not self.epoch_times:
            return {"mean": None, "std": None, "n": 0}
        arr = np.array(self.epoch_times, dtype=float)
        return {"mean": float(arr.mean()), "std": float(arr.std()), "n": int(arr.size)}
        
    def start_monitoring(self):
        self.start_time = time.time()
        self.initial_memory_mb = self._get_memory_usage()
        self.peak_memory_mb = self.initial_memory_mb
        
        if torch.cuda.is_available():
            self.initial_gpu_memory_mb = torch.cuda.memory_allocated() / 1024**2
            self.peak_gpu_memory_mb = self.initial_gpu_memory_mb
        
        print(f"\n🔍 Iniciando monitoramento: {self.model_name}")
        print(f"  • Initial RAM: {self.initial_memory_mb:.2f} MB")
        if torch.cuda.is_available():
            print(f"  • Initial GPU: {self.initial_gpu_memory_mb:.2f} MB")
        
    def _get_memory_usage(self):
        return self.process.memory_info().rss / 1024 / 1024
        
    def update_peak_memory(self):
        current_memory = self._get_memory_usage()
        if current_memory > self.peak_memory_mb:
            self.peak_memory_mb = current_memory
        
        if torch.cuda.is_available():
            current_gpu = torch.cuda.max_memory_allocated() / 1024**2
            if current_gpu > self.peak_gpu_memory_mb:
                self.peak_gpu_memory_mb = current_gpu
            
    def end_monitoring(self):
        self.end_time = time.time()
        self.training_time = self.end_time - self.start_time
        final_memory_mb = self._get_memory_usage()
        memory_increase = final_memory_mb - self.initial_memory_mb
        
        print("\n" + "="*70)
        print(f"MONITORING REPORT: {self.model_name.upper()}")
        print("="*70)
        print(f"Total training time: {timedelta(seconds=int(self.training_time))}")
        print(f"Initial RAM: {self.initial_memory_mb:.2f} MB")
        print(f"Final RAM: {final_memory_mb:.2f} MB")
        print(f"Peak RAM: {self.peak_memory_mb:.2f} MB")
        print(f"Memory increase: {memory_increase:.2f} MB")
        
        if torch.cuda.is_available():
            final_gpu = torch.cuda.memory_allocated() / 1024**2
            print(f"Peak GPU Memory: {self.peak_gpu_memory_mb:.2f} MB")
            print(f"Final GPU Memory: {final_gpu:.2f} MB")
        
        print("="*70)
        
        return {
            'training_time_seconds': self.training_time,
            'initial_memory_mb': self.initial_memory_mb,
            'final_memory_mb': final_memory_mb,
            'peak_memory_mb': self.peak_memory_mb,
            'memory_increase_mb': memory_increase,
            'peak_gpu_memory_mb': self.peak_gpu_memory_mb if torch.cuda.is_available() else 0
        }

# %%
# =============================================================================
# CLASSE DE EARLY STOPPING
# =============================================================================

class EarlyStopping:
    """
    Early Stopping para interromper o treinamento quando a métrica de validação
    não melhora por um número específico de épocas (patience).
    """
    def __init__(self, patience=10, min_delta=0.0, mode='max', verbose=True):
        """
        Args:
            patience (int): Número de épocas sem melhoria antes de parar
            min_delta (float): Mudança mínima para considerar melhoria
            mode (str): 'max' para métricas que devem aumentar (F1, acc),
                       'min' para métricas que devem diminuir (loss)
            verbose (bool): Se True, imprime mensagens
        """
        self.patience = patience
        self.min_delta = min_delta
        self.mode = mode
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_score_min = np.inf if mode == 'min' else -np.inf
        
    def __call__(self, val_score):
        """
        Verifica se deve parar o treinamento
        
        Args:
            val_score (float): Métrica de validação atual
            
        Returns:
            bool: True se deve parar o treinamento
        """
        if self.mode == 'max':
            score = val_score
        else:
            score = -val_score
            
        if self.best_score is None:
            self.best_score = score
            self.val_score_min = val_score
            if self.verbose:
                print(f'Early Stopping: Baseline estabelecida: {val_score:.4f}')
        elif score < self.best_score + self.min_delta:
            self.counter += 1
            if self.verbose:
                print(f'Early Stopping: Sem melhoria ({self.counter}/{self.patience})')
            if self.counter >= self.patience:
                self.early_stop = True
                if self.verbose:
                    print(f'Early Stopping: Treinamento interrompido após {self.patience} épocas sem melhoria')
        else:
            if self.verbose:
                improvement = val_score - self.val_score_min
                print(f'Early Stopping: Melhoria detectada ({val_score:.4f}, Delta={improvement:+.4f})')
            self.best_score = score
            self.val_score_min = val_score
            self.counter = 0
            
        return self.early_stop

print("Classe Early Stopping configurada")
# Out:
# Classe Early Stopping configurada

# %%
# =============================================================================
# DATASET CUSTOMIZADO (SEM AUGMENTATION)
# =============================================================================

class EmotionDataset(Dataset):
    """
    Dataset personalizado para reconhecimento de emoções.
    Apenas normaliza para uso com modelos pré-treinados.
    """
    def __init__(self, root_dir, split='train'):
        self.root_dir = os.path.join(root_dir, split)
        self.image_paths = []
        self.labels = []

        # Carregar todos os caminhos de imagem e rótulos
        for class_name, class_idx in EMOTION_LABELS.items():
            class_path = os.path.join(self.root_dir, class_name)
            if os.path.isdir(class_path):
                for img_name in os.listdir(class_path):
                    if img_name.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp')):
                        self.image_paths.append(os.path.join(class_path, img_name))
                        self.labels.append(class_idx)

        if len(self.image_paths) == 0:
            raise ValueError(f"Nenhuma imagem encontrada em {self.root_dir}. Verifique o caminho!")
        
        print(f"\n{split.upper()} Dataset:")
        print(f"   Total de imagens: {len(self.image_paths)}")
        
        # Contar amostras por classe
        label_counts = pd.Series(self.labels).value_counts().sort_index()
        for idx, count in label_counts.items():
            emotion_name = [k for k, v in EMOTION_LABELS.items() if v == idx][0]
            print(f"   {emotion_name:12s}: {count:5d} imagens")

    def __len__(self):
        return len(self.image_paths)
    
    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        label = self.labels[idx]

        # Ler imagem em escala de cinza (já pré-processada em 224x224)
        image = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

        if image is None:
            raise ValueError(f"Erro ao carregar imagem: {img_path}")
        
        # Normalizar para [0, 1]
        image = image.astype(np.float32) / 255.0
        
        # Normalização com média e desvio padrão (para modelos pré-treinados)
        # Usando normalização simples para grayscale
        image = (image - 0.5) / 0.5
        
        # Adicionar dimensão de canal e converter para tensor
        image = np.expand_dims(image, axis=0)  # [H, W] -> [1, H, W]
        image = torch.from_numpy(image).float()

        return image, torch.tensor(label, dtype=torch.long)

print("Classe Dataset configurada")
# Out:
# Classe Dataset configurada

# %%
# =============================================================================
# DEFINIÇÃO DOS MODELOS
# =============================================================================

def create_model(model_name, num_classes=7):
    """
    Cria modelo baseado no nome.
    
    Args:
        model_name: 'resnet50', 'efficientnet_b0', ou 'efficientvit_m5'
        num_classes: Número de classes (7 emoções)
    
    Returns:
        model: Modelo PyTorch
    """
    if model_name == 'resnet50':
        model = models.resnet50(weights='IMAGENET1K_V1')
        
        # Primeira camada adaptada para grayscale (1 canal)
        original_weights = model.conv1.weight.data
        avg_weights = torch.mean(original_weights, dim=1, keepdim=True)
        model.conv1 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)
        model.conv1.weight.data = avg_weights
        
        # Camada final para número de classes
        num_features = model.fc.in_features
        model.fc = nn.Linear(num_features, num_classes)
    
    elif model_name == 'efficientnet_b0':
        model = models.efficientnet_b0(weights='IMAGENET1K_V1')
        
        # Primeira camada adaptada para grayscale (1 canal)
        original_weights = model.features[0][0].weight.data
        avg_weights = torch.mean(original_weights, dim=1, keepdim=True)
        model.features[0][0] = nn.Conv2d(1, 32, kernel_size=3, stride=2, padding=1, bias=False)
        model.features[0][0].weight.data = avg_weights
        
        # Camada final para número de classes
        num_features = model.classifier[1].in_features
        model.classifier[1] = nn.Linear(num_features, num_classes)

    elif model_name == 'efficientvit_m5':
        try:
            import timm
            model = timm.create_model('efficientvit_m5', pretrained=True, num_classes=num_classes, in_chans=1)
        except ImportError:
            print("timm não instalado. Execute: pip install timm")
            return None
        except Exception as e:
            print(f"Erro ao criar EfficientViT: {e}")
            return None
    else:
        raise ValueError(f"Modelo não suportado: {model_name}")
    
    # Contar parâmetros
    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    
    print(f"Modelo '{model_name}' criado com sucesso")
    print(f"   Total de parâmetros: {total_params:,}")
    print(f"   Parâmetros treináveis: {trainable_params:,}")
    
    return model

print("Função de criação de modelos configurada")
# Out:
# Função de criação de modelos configurada

# %%
# =============================================================================
# FUNÇÕES DE TREINAMENTO
# =============================================================================

def train_epoch(model, train_loader, criterion, optimizer, device, scaler, monitor):
    """
    Treina o modelo por uma época.
    """
    model.train()
    running_loss = 0.0
    
    for batch_idx, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)
        
        # Forward pass com mixed precision
        with torch.cuda.amp.autocast(enabled=(device == "cuda")):
            outputs = model(images)
            loss = criterion(outputs, labels)
        
        # Backward pass
        optimizer.zero_grad()
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        
        running_loss += loss.item()
        
        # Atualizar monitoramento de memória a cada 50 batches
        if batch_idx % 50 == 0:
            monitor.update_peak_memory()
    
    return running_loss / len(train_loader)


def validate(model, val_loader, device):
    """
    Valida o modelo.
    """
    model.eval()
    all_preds = []
    all_labels = []
    
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            
            with torch.cuda.amp.autocast(enabled=(device == "cuda")):
                outputs = model(images)
            
            preds = torch.argmax(outputs, dim=1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    
    return np.array(all_preds), np.array(all_labels)


def train_model(model_name, train_loader, val_loader, device, epochs, early_stopping):
    """
    Treina um modelo completo com monitoramento.
    """
    print(f"\n{'='*80}")
    print(f"TREINANDO: {model_name.upper()}")
    print(f"{'='*80}")
    
    # Inicializar monitor
    monitor = ResourceMonitor(model_name)
    monitor.start_monitoring()
    
    # Criar modelo
    model = create_model(model_name)
    if model is None:
        return None
    
    model.to(device)
    
    # Configuração de treinamento
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(model.parameters(), lr=LR)
    scaler = torch.cuda.amp.GradScaler(enabled=(device == "cuda"))
    
    # Histórico
    history = {
        'train_loss': [],
        'val_accuracy': [],
        'val_f1_macro': [],
        'val_precision': [],
        'val_recall': [],
        'combined_metric': []
    }
    
    best_combined_metric = 0.0
    best_val_f1 = 0.0
    best_val_accuracy = 0.0
    best_epoch = 0
    best_model_path = os.path.join(MODELS_PATH, f"{model_name}_best.pth")
    
    # Loop de treinamento
    for epoch in range(epochs):
        epoch_start = time.time()
        
        # Treinar
        train_loss = train_epoch(model, train_loader, criterion, optimizer, device, scaler, monitor)
        
        # Validar
        val_preds, val_labels = validate(model, val_loader, device)
        
        # Calcular métricas
        val_accuracy = accuracy_score(val_labels, val_preds)
        val_f1_macro = f1_score(val_labels, val_preds, average='macro')
        val_precision = precision_score(val_labels, val_preds, average='macro', zero_division=0)
        val_recall = recall_score(val_labels, val_preds, average='macro', zero_division=0)
        
        # Métrica combinada
        combined_metric = (F1_WEIGHT * val_f1_macro) + (ACC_WEIGHT * val_accuracy)
        
        # Salvar histórico
        history['train_loss'].append(train_loss)
        history['val_accuracy'].append(val_accuracy)
        history['val_f1_macro'].append(val_f1_macro)
        history['val_precision'].append(val_precision)
        history['val_recall'].append(val_recall)
        history['combined_metric'].append(combined_metric)
        
        epoch_time = time.time() - epoch_start
        monitor.record_epoch_time(epoch_time)
        
        # Relatório da época
        print(f"\nÉpoca [{epoch+1}/{epochs}] - Tempo: {epoch_time:.2f}s")
        print(f"   Train Loss: {train_loss:.4f}")
        print(f"   Val Acc: {val_accuracy:.4f} | Val F1: {val_f1_macro:.4f}")
        print(f"   Val Precision: {val_precision:.4f} | Val Recall: {val_recall:.4f}")
        print(f"   Métrica Combinada: {combined_metric:.4f}")
        
        # Salvar melhor modelo
        if combined_metric > best_combined_metric:
            best_combined_metric = combined_metric
            best_val_f1 = val_f1_macro
            best_val_accuracy = val_accuracy
            best_epoch = epoch
            
            # Salvar checkpoint completo em .pth
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'best_combined_metric': best_combined_metric,
                'best_val_f1': best_val_f1,
                'best_val_accuracy': best_val_accuracy,
                'history': history,
                'model_name': model_name
            }, best_model_path)
            
            print(f"   Modelo salvo: {best_model_path}")
        
        # Verificar early stopping
        if early_stopping(combined_metric):
            print(f"\nEarly stopping ativado na época {epoch+1}")
            break
    
    # Finalizar monitoramento
    monitoring_stats = monitor.end_monitoring()
    
    # Carregar melhor modelo
    checkpoint = torch.load(best_model_path)
    model.load_state_dict(checkpoint['model_state_dict'])
    
    return {
        'model': model,
        'model_name': model_name,
        'best_epoch': best_epoch,
        'best_val_accuracy': best_val_accuracy,
        'best_val_f1': best_val_f1,
        'best_combined_metric': best_combined_metric,
        'history': history,
        'monitoring_stats': monitoring_stats,
        'model_path': best_model_path,
        'epochs_completed': epoch + 1
    }

print("Funções de treinamento configuradas")
# Out:
# Funções de treinamento configuradas

# %%
# =============================================================================
# AVALIAÇÃO COM MATRIZ NORMALIZADA
# =============================================================================

def evaluate_model(model, test_loader, device):
    """
    Avalia modelo com métricas completas incluindo matriz de confusão normalizada.
    """
    print("\nAvaliando modelo no conjunto de teste...")
    
    model.eval()
    all_preds = []
    all_labels = []
    
    with torch.no_grad():
        for images, labels in tqdm(test_loader, desc="Testando"):
            images, labels = images.to(device), labels.to(device)
            
            with torch.cuda.amp.autocast(enabled=(device == "cuda")):
                outputs = model(images)
            
            preds = torch.argmax(outputs, dim=1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    
    all_preds = np.array(all_preds)
    all_labels = np.array(all_labels)
    
    # Calcular métricas
    test_accuracy = accuracy_score(all_labels, all_preds)
    test_f1_macro = f1_score(all_labels, all_preds, average='macro')
    test_f1_weighted = f1_score(all_labels, all_preds, average='weighted')
    test_precision = precision_score(all_labels, all_preds, average='macro', zero_division=0)
    test_recall = recall_score(all_labels, all_preds, average='macro', zero_division=0)
    
    # Métricas por classe
    precision_per_class, recall_per_class, f1_per_class, support = precision_recall_fscore_support(
        all_labels, all_preds, average=None, zero_division=0
    )
    
    # Matrizes de confusão
    conf_matrix = confusion_matrix(all_labels, all_preds)
    conf_matrix_normalized = confusion_matrix(all_labels, all_preds, normalize='true')
    
    # Relatório de classificação
    emotion_names = [k for k, v in sorted(EMOTION_LABELS.items(), key=lambda x: x[1])]
    class_report = classification_report(
        all_labels, all_preds,
        target_names=emotion_names,
        output_dict=True,
        zero_division=0
    )
    
    # Imprimir resultados
    print(f"\n{'='*70}")
    print("RESULTADOS DA AVALIAÇÃO - CONJUNTO DE TESTE")
    print(f"{'='*70}")
    print(f"Acurácia: {test_accuracy:.4f}")
    print(f"\nMétricas Macro:")
    print(f"   Precisão: {test_precision:.4f}")
    print(f"   Recall: {test_recall:.4f}")
    print(f"   F1-Score: {test_f1_macro:.4f}")
    print(f"\nF1-Score Weighted: {test_f1_weighted:.4f}")
    print(f"{'='*70}\n")
    
    # Imprimir métricas por classe
    print("\nMétricas por Classe:")
    print(f"{'Classe':<15} {'Precisão':<12} {'Recall':<12} {'F1-Score':<12} {'Suporte':<10}")
    print("-" * 70)
    for i, emotion in enumerate(emotion_names):
        print(f"{emotion:<15} {precision_per_class[i]:<12.4f} {recall_per_class[i]:<12.4f} "
              f"{f1_per_class[i]:<12.4f} {support[i]:<10}")
    print("-" * 70)
    
    return {
        'test_accuracy': test_accuracy,
        'test_f1_macro': test_f1_macro,
        'test_f1_weighted': test_f1_weighted,
        'test_precision': test_precision,
        'test_recall': test_recall,
        'confusion_matrix': conf_matrix,
        'confusion_matrix_normalized': conf_matrix_normalized,
        'classification_report': class_report,
        'predictions': all_preds,
        'labels': all_labels
    }

print("Função de avaliação configurada")
# Out:
# Função de avaliação configurada

# %%
def create_comprehensive_visualizations(history, conf_matrix, metrics, class_report, 
                                       experiment_id, y_true, y_pred, model_name, 
                                       train_distribution):
    """
    Visualizações completas com comparação train vs test.
    
    Args:
        train_distribution: dict com contagem de classes do treino
                           formato: {0: count, 1: count, ...}
    """
    fig = plt.figure(figsize=(24, 18))
    emotion_names = list(EMOTION_LABELS.keys())
    
    # 1. ACCURACY
    ax1 = plt.subplot(3, 4, 1)
    epochs = range(1, len(history['val_accuracy']) + 1)
    plt.plot(epochs, [acc * 100 for acc in history['val_accuracy']], 
             'b-', linewidth=2, label='Val Accuracy', marker='o', markersize=3)
    plt.title(f'{model_name.upper()}: Accuracy Evolution', fontsize=14, fontweight='bold')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.legend(fontsize=10)
    plt.grid(True, alpha=0.3)
    
    # 2. LOSS
    ax2 = plt.subplot(3, 4, 2)
    plt.plot(epochs, history['train_loss'], 
             'r-', linewidth=2, label='Train Loss', marker='o', markersize=3)
    plt.title(f'{model_name.upper()}: Loss Evolution', fontsize=14, fontweight='bold')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(fontsize=10)
    plt.grid(True, alpha=0.3)
    
    # 3. MATRIZ RAW
    ax3 = plt.subplot(3, 4, 3)
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
                xticklabels=emotion_names, yticklabels=emotion_names, ax=ax3,
                cbar_kws={'label': 'Amostras'})
    plt.title('Matriz de Confusão (Test)', fontsize=12, fontweight='bold')
    plt.ylabel('Classe Verdadeira')
    plt.xlabel('Classe Predita')
    plt.xticks(rotation=45)
    plt.yticks(rotation=0)
    
    # 4. MATRIZ NORMALIZADA
    ax4 = plt.subplot(3, 4, 4)
    conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]
    conf_matrix_norm = np.nan_to_num(conf_matrix_norm)
    sns.heatmap(conf_matrix_norm, annot=True, fmt='.3f', cmap='Greens',
                xticklabels=emotion_names, yticklabels=emotion_names, ax=ax4,
                cbar_kws={'label': 'Proporção'})
    plt.title('Matriz Normalizada (Recall)', fontsize=12, fontweight='bold')
    plt.ylabel('Classe Verdadeira')
    plt.xlabel('Classe Predita')
    plt.xticks(rotation=45)
    plt.yticks(rotation=0)
    
    # 5. DISTRIBUIÇÃO TRAIN VS TEST ← MODIFICADO
    ax5 = plt.subplot(3, 4, 5)
    
    # Dados do TESTE
    unique_test, counts_test = np.unique(y_true, return_counts=True)
    test_dist = dict(zip(unique_test, counts_test))
    
    # Organizar dados para plotagem
    train_counts = [train_distribution.get(i, 0) for i in range(len(emotion_names))]
    test_counts = [test_dist.get(i, 0) for i in range(len(emotion_names))]
    
    x = np.arange(len(emotion_names))
    width = 0.35
    
    bars1 = plt.bar(x - width/2, train_counts, width, label='Train (Balanceado)', 
                   alpha=0.8, color='steelblue', edgecolor='black')
    bars2 = plt.bar(x + width/2, test_counts, width, label='Test (Original)', 
                   alpha=0.8, color='coral', edgecolor='black')
    
    plt.title('Distribuição: Train vs Test', fontsize=12, fontweight='bold')
    plt.ylabel('Amostras')
    plt.xlabel('Emoção')
    plt.xticks(x, emotion_names, rotation=45)
    plt.legend()
    plt.grid(True, alpha=0.3, axis='y')
    
    # Adicionar valores nas barras
    for bars in [bars1, bars2]:
        for bar in bars:
            height = bar.get_height()
            plt.text(bar.get_x() + bar.get_width()/2, height + max(train_counts + test_counts)*0.01,
                    f'{int(height)}', ha='center', va='bottom', fontsize=8)
    
    # 6. F1-SCORE (Test)
    ax6 = plt.subplot(3, 4, 6)
    f1_scores = [class_report[emotion]['f1-score'] for emotion in emotion_names]
    support_counts = [class_report[emotion]['support'] for emotion in emotion_names]
    bars = plt.bar(emotion_names, f1_scores, color='steelblue', alpha=0.8, edgecolor='black')
    plt.title('F1-Score por Emoção (Test)', fontsize=12, fontweight='bold')
    plt.ylabel('F1-Score')
    plt.xticks(rotation=45)
    plt.ylim(0, 1)
    for bar, score, support in zip(bars, f1_scores, support_counts):
        plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01,
                f'{score:.3f}\n(n={support})', ha='center', va='bottom', fontsize=9)
    
    # 7. PRECISION, RECALL, F1
    ax7 = plt.subplot(3, 4, 7)
    precision_scores = [class_report[emotion]['precision'] for emotion in emotion_names]
    recall_scores = [class_report[emotion]['recall'] for emotion in emotion_names]
    x = np.arange(len(emotion_names))
    width = 0.25
    bars1 = plt.bar(x - width, precision_scores, width, label='Precision', alpha=0.8, color='lightcoral')
    bars2 = plt.bar(x, recall_scores, width, label='Recall', alpha=0.8, color='lightblue')
    bars3 = plt.bar(x + width, f1_scores, width, label='F1-Score', alpha=0.8, color='lightgreen')
    plt.title('Métricas por Classe (Test)', fontsize=12, fontweight='bold')
    plt.ylabel('Score')
    plt.xlabel('Emoção')
    plt.xticks(x, emotion_names, rotation=45)
    plt.legend()
    plt.ylim(0, 1)
    
    # 8. F1 MACRO VS WEIGHTED
    ax8 = plt.subplot(3, 4, 8)
    precision_macro, recall_macro, f1_macro, _ = precision_recall_fscore_support(
        y_true, y_pred, average='macro', zero_division=0)
    precision_weighted, recall_weighted, f1_weighted, _ = precision_recall_fscore_support(
        y_true, y_pred, average='weighted', zero_division=0)
    metrics_comparison = {
        'Precision': [precision_macro, precision_weighted],
        'Recall': [recall_macro, recall_weighted],
        'F1-Score': [f1_macro, f1_weighted]
    }
    x = np.arange(len(metrics_comparison))
    width = 0.35
    macro_values = [metrics_comparison[metric][0] for metric in metrics_comparison]
    weighted_values = [metrics_comparison[metric][1] for metric in metrics_comparison]
    bars1 = plt.bar(x - width/2, macro_values, width, label='Macro', alpha=0.8, color='lightcoral')
    bars2 = plt.bar(x + width/2, weighted_values, width, label='Weighted', alpha=0.8, color='lightblue')
    plt.title('Macro vs Weighted (Test)', fontsize=12, fontweight='bold')
    plt.ylabel('Score')
    plt.xlabel('Métrica')
    plt.xticks(x, metrics_comparison.keys())
    plt.legend()
    plt.ylim(0, 1)
    for bars in [bars1, bars2]:
        for bar in bars:
            height = bar.get_height()
            plt.text(bar.get_x() + bar.get_width()/2, height + 0.01,
                    f'{height:.3f}', ha='center', va='bottom', fontsize=10)
    
    # 9. HEATMAP ERROS
    ax9 = plt.subplot(3, 4, 9)
    error_matrix = conf_matrix.copy()
    np.fill_diagonal(error_matrix, 0)
    error_matrix_norm = error_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]
    error_matrix_norm = np.nan_to_num(error_matrix_norm)
    sns.heatmap(error_matrix_norm, annot=True, fmt='.3f', cmap='Reds',
                xticklabels=emotion_names, yticklabels=emotion_names, ax=ax9,
                cbar_kws={'label': 'Proporção de Erros'})
    plt.title('Heatmap de Erros (Test)', fontsize=12, fontweight='bold')
    plt.ylabel('Classe Verdadeira')
    plt.xlabel('Classe Predita')
    plt.xticks(rotation=45)
    plt.yticks(rotation=0)
    
    # 10. F1 POR ÉPOCA
    ax10 = plt.subplot(3, 4, 10)
    plt.plot(epochs, history['val_f1_macro'], 'g-', linewidth=2, 
             label='Val F1-Macro', marker='o', markersize=3)
    plt.title('F1-Score Evolution', fontsize=12, fontweight='bold')
    plt.xlabel('Epoch')
    plt.ylabel('F1-Score')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # 11. RECURSOS COMPUTACIONAIS
    ax11 = plt.subplot(3, 4, 11)
    resource_data = {
        'Tempo (min)': metrics['training_time_seconds'] / 60,
        'Memória (GB)': metrics['peak_memory_mb'] / 1024,
        'Parâmetros (M)': metrics['total_parameters'] / 1_000_000,
        'Eficiência': metrics['test_accuracy'] / (metrics['total_parameters'] / 1_000_000)
    }
    colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']
    bars = plt.bar(range(len(resource_data)), list(resource_data.values()), 
                  color=colors, alpha=0.7, edgecolor='black')
    plt.title(f'Recursos Computacionais\n{model_name.upper()}', fontsize=12, fontweight='bold')
    plt.xticks(range(len(resource_data)), resource_data.keys(), rotation=45)
    plt.ylabel('Valor')
    for bar, (key, value) in zip(bars, resource_data.items()):
        plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + bar.get_height()*0.02,
                f'{value:.2f}', ha='center', va='bottom', fontweight='bold')
    
    # 12. RESUMO
    ax12 = plt.subplot(3, 4, 12)
    ax12.axis('off')
    
    # Calcular diferença de balanceamento
    train_max = max(train_counts)
    train_min = min(train_counts)
    test_max = max(test_counts)
    test_min = min(test_counts)
    train_ratio = train_max / train_min if train_min > 0 else 0
    test_ratio = test_max / test_min if test_min > 0 else 0
    
    summary_text = f"""
{model_name.upper()}
RESUMO

PERFORMANCE (Test):
- Accuracy: {metrics['test_accuracy']:.4f}
- F1-Macro: {f1_macro:.4f}
- F1-Weighted: {f1_weighted:.4f}

DISTRIBUIÇÃO:
- Train Ratio: {train_ratio:.1f}:1
- Test Ratio: {test_ratio:.1f}:1

RECURSOS:
- Parâmetros: {metrics['total_parameters']/1_000_000:.1f}M
- Tempo: {metrics['training_time_seconds']/60:.1f} min
- Memória: {metrics['peak_memory_mb']/1024:.2f} GB

MELHOR/PIOR (Test):
- Melhor: {emotion_names[np.argmax(f1_scores)]} ({max(f1_scores):.3f})
- Pior: {emotion_names[np.argmin(f1_scores)]} ({min(f1_scores):.3f})
    """
    ax12.text(0.05, 0.95, summary_text, fontsize=11, verticalalignment='top',
             transform=ax12.transAxes,
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
    
    plt.tight_layout()
    plt.savefig(os.path.join(PLOTS_PATH, f'{model_name}_analysis_{experiment_id}.png'), 
                dpi=300, bbox_inches='tight')
    plt.show()

# %%
# =============================================================================
# FUNÇÕES DE VISUALIZAÇÃO
# =============================================================================

def plot_confusion_matrices(conf_matrix, conf_matrix_normalized, model_name, save_path):
    """
    Plota matrizes de confusão (raw e normalizada).
    """
    emotion_names = [k for k, v in sorted(EMOTION_LABELS.items(), key=lambda x: x[1])]
    
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    
    # Matriz Raw
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
                xticklabels=emotion_names, yticklabels=emotion_names, ax=axes[0],
                cbar_kws={'label': 'Amostras'})
    axes[0].set_title(f'{model_name.upper()}: Matriz de Confusão (Raw)', fontsize=14, fontweight='bold')
    axes[0].set_ylabel('Classe Verdadeira')
    axes[0].set_xlabel('Classe Predita')
    
    # Matriz Normalizada
    sns.heatmap(conf_matrix_normalized, annot=True, fmt='.3f', cmap='Greens',
                xticklabels=emotion_names, yticklabels=emotion_names, ax=axes[1],
                cbar_kws={'label': 'Proporção'})
    axes[1].set_title(f'{model_name.upper()}: Matriz Normalizada (Recall)', fontsize=14, fontweight='bold')
    axes[1].set_ylabel('Classe Verdadeira')
    axes[1].set_xlabel('Classe Predita')
    
    plt.tight_layout()
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    plt.close()
    print(f"Matrizes de confusão salvas: {save_path}")

def plot_training_history(history, model_name, save_path):
    """
    Plota histórico de treinamento (Loss, Accuracy, F1).
    """
    epochs = range(1, len(history['train_loss']) + 1)
    
    fig, axes = plt.subplots(1, 3, figsize=(18, 5))
    
    # Loss
    axes[0].plot(epochs, history['train_loss'], 'b-', linewidth=2, label='Train Loss', marker='o')
    axes[0].set_title(f'{model_name.upper()}: Loss Evolution', fontsize=12, fontweight='bold')
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[0].grid(True, alpha=0.3)
    
    # Accuracy
    axes[1].plot(epochs, [acc * 100 for acc in history['val_accuracy']], 
                 'g-', linewidth=2, label='Val Accuracy', marker='o')
    axes[1].set_title(f'{model_name.upper()}: Accuracy Evolution', fontsize=12, fontweight='bold')
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('Accuracy (%)')
    axes[1].legend()
    axes[1].grid(True, alpha=0.3)
    
    # F1-Score
    axes[2].plot(epochs, history['val_f1_macro'], 'r-', linewidth=2, label='Val F1-Macro', marker='o')
    axes[2].set_title(f'{model_name.upper()}: F1-Score Evolution', fontsize=12, fontweight='bold')
    axes[2].set_xlabel('Epoch')
    axes[2].set_ylabel('F1-Score')
    axes[2].legend()
    axes[2].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    plt.close()
    print(f"Histórico de treinamento salvo: {save_path}")

# %%
# =============================================================================
# SALVAR RESULTADOS
# =============================================================================

def save_results(model_name, train_result, eval_result):
    """
    Salva todos os resultados do experimento.
    """
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    
    # Salvar métricas como JSON
    metrics = {
        'model_name': model_name,
        'timestamp': timestamp,
        'best_epoch': int(train_result['best_epoch']),
        'epochs_completed': int(train_result['epochs_completed']),
        'best_val_accuracy': float(train_result['best_val_accuracy']),
        'best_val_f1': float(train_result['best_val_f1']),
        'test_accuracy': float(eval_result['test_accuracy']),
        'test_f1_macro': float(eval_result['test_f1_macro']),
        'test_f1_weighted': float(eval_result['test_f1_weighted']),
        'test_precision': float(eval_result['test_precision']),
        'test_recall': float(eval_result['test_recall']),
        'monitoring_stats': train_result['monitoring_stats']
    }
    
    metrics_path = os.path.join(METRICS_PATH, f"{model_name}_metrics_{timestamp}.json")
    with open(metrics_path, 'w') as f:
        json.dump(metrics, f, indent=4)
    print(f"Métricas salvas: {metrics_path}")
    
    # Salvar matrizes de confusão como CSV
    emotion_names = [k for k, v in sorted(EMOTION_LABELS.items(), key=lambda x: x[1])]
    
    conf_matrix_df = pd.DataFrame(
        eval_result['confusion_matrix'],
        index=emotion_names,
        columns=emotion_names
    )
    conf_matrix_df.to_csv(os.path.join(METRICS_PATH, f"{model_name}_confusion_raw_{timestamp}.csv"))
    
    conf_matrix_norm_df = pd.DataFrame(
        eval_result['confusion_matrix_normalized'],
        index=emotion_names,
        columns=emotion_names
    )
    conf_matrix_norm_df.to_csv(os.path.join(METRICS_PATH, f"{model_name}_confusion_normalized_{timestamp}.csv"))
    
    # Salvar visualizações
    plot_confusion_matrices(
        eval_result['confusion_matrix'],
        eval_result['confusion_matrix_normalized'],
        model_name,
        save_path=os.path.join(PLOTS_PATH, f"{model_name}_confusion_{timestamp}.png")
    )
    
    plot_training_history(
        train_result['history'],
        model_name,
        save_path=os.path.join(PLOTS_PATH, f"{model_name}_history_{timestamp}.png")
    )
    
    print(f"\nTodos os resultados salvos para {model_name}")
    
    return metrics

print("Função de salvamento configurada")
# Out:
# Função de salvamento configurada

# %%
# =============================================================================
# EXECUÇÃO PRINCIPAL
# =============================================================================

def main():
    """
    Função principal de execução.
    """
    print(f"\n{'='*80}")
    print("INICIANDO TREINAMENTO BASELINE")
    print(f"{'='*80}\n")
    
    # Carregar datasets
    print("Carregando datasets...")
    train_dataset = EmotionDataset(DATASET_PATH, split='train')

    # Calcular distribuição do conjunto de treino
    train_distribution = {}
    for _, label in train_dataset:
        label_int = int(label)
        train_distribution[label_int] = train_distribution.get(label_int, 0) + 1
    test_dataset = EmotionDataset(DATASET_PATH, split='test')
    
    # Criar data loaders
    train_loader = DataLoader(
        train_dataset,
        batch_size=BATCH_SIZE,
        shuffle=True,
        num_workers=NUM_WORKERS,
        pin_memory=True,
        drop_last=True
    )
    
    test_loader = DataLoader(
        test_dataset,
        batch_size=BATCH_SIZE,
        shuffle=False,
        num_workers=NUM_WORKERS,
        pin_memory=True
    )
    
    print(f"\nDatasets carregados com sucesso")
    print(f"Train samples: {len(train_dataset)}")
    print(f"Test samples: {len(test_dataset)}")
    
    # Lista de modelos para treinar
    models_to_train = ['resnet50', 'efficientnet_b0', 'efficientvit_m5']
    
    all_results = []
    
    # Treinar cada modelo
    for model_name in models_to_train:
        try:
            # Inicializar early stopping
            early_stopping = EarlyStopping(
                patience=EARLY_STOP_PATIENCE,
                min_delta=EARLY_STOP_MIN_DELTA,
                mode='max',
                verbose=True
            )
            
            # Treinar
            train_result = train_model(
                model_name,
                train_loader,
                test_loader,
                DEVICE,
                EPOCHS,
                early_stopping
            )
            
            if train_result is None:
                continue
            
            # Avaliar
            eval_result = evaluate_model(train_result['model'], test_loader, DEVICE)
            
            # Salvar resultados
            metrics = save_results(model_name, train_result, eval_result)
            all_results.append(metrics)
            
            # Limpar memória
            del train_result, eval_result
            if torch.cuda.is_available():
                torch.cuda.empty_cache()
            gc.collect()
            
        except Exception as e:
            print(f"\nErro ao treinar {model_name}: {type(e).__name__}")
            print(f"Mensagem: {e}")
            import traceback
            traceback.print_exc()
            continue
    
    # Comparação final
    if all_results:
        print(f"\n{'='*80}")
        print("COMPARAÇÃO FINAL - TODOS OS MODELOS")
        print(f"{'='*80}\n")
        
        comparison_df = pd.DataFrame(all_results)
        print(comparison_df[['model_name', 'test_accuracy', 'test_f1_macro', 
                            'test_f1_weighted', 'epochs_completed']].to_string(index=False))
        
        # Salvar comparação
        comparison_path = os.path.join(METRICS_PATH, 'model_comparison.csv')
        comparison_df.to_csv(comparison_path, index=False)
        print(f"\nComparação salva: {comparison_path}")
        
        # Identificar melhor modelo
        best_model = comparison_df.loc[comparison_df['test_accuracy'].idxmax()]
        print(f"\nMelhor modelo (por acurácia): {best_model['model_name']} - {best_model['test_accuracy']:.4f}")
    
    print(f"\n{'='*80}")
    print("TREINAMENTO BASELINE CONCLUÍDO")
    print(f"{'='*80}\n")

print("Função principal configurada")
# Out:
# Função principal configurada

# %%
# =============================================================================
# EXECUTAR
# =============================================================================

if __name__ == "__main__":
    try:
        main()
    except KeyboardInterrupt:
        print("\n\nInterrompido pelo usuário")
    except Exception as e:
        print(f"\n\nERRO: {type(e).__name__}")
        print(f"Mensagem: {e}")
        import traceback
        print("\nTraceback:")
        traceback.print_exc()
# Out:
# ================================================================================
# INICIANDO TREINAMENTO BASELINE
# ================================================================================
#
# Carregando datasets...
#
# TRAIN Dataset:
#    Total de imagens: 12271
#    Raiva       :   705 imagens
#    Nojo        :   717 imagens
#    Medo        :   281 imagens
#    Felicidade  :  4772 imagens
#    Neutro      :  2524 imagens
#    Tristeza    :  1982 imagens
#    Surpresa    :  1290 imagens
#
# TEST Dataset:
#    Total de imagens: 3068
#    Raiva       :   162 imagens
#    Nojo        :   160 imagens
#    Medo        :    74 imagens
#    Felicidade  :  1185 imagens
#    Neutro      :   680 imagens
#    Tristeza    :   478 imagens
#    Surpresa    :   329 imagens
#
# Datasets carregados com sucesso
# Train samples: 12271
# Test samples: 3068
#
# ================================================================================
# TREINANDO: RESNET50
# ================================================================================
#
# 🔍 Iniciando monitoramento: resnet50
#   • Initial RAM: 730.14 MB
#   • Initial GPU: 0.00 MB
# Modelo 'resnet50' criado com sucesso
#    Total de parâmetros: 23,516,103
#    Parâmetros treináveis: 23,516,103
#
# Época [1/100] - Tempo: 32.51s
#    Train Loss: 1.0340
#    Val Acc: 0.7220 | Val F1: 0.6082
#    Val Precision: 0.6583 | Val Recall: 0.6042
#    Métrica Combinada: 0.6537
#    Modelo salvo: ../results/baseline/RAF-DB/models/resnet50_best.pth
# Early Stopping: Baseline estabelecida: 0.6537
#
# Época [2/100] - Tempo: 32.34s
#    Train Loss: 0.5902
#    Val Acc: 0.7588 | Val F1: 0.6665
#    Val Precision: 0.6894 | Val Recall: 0.6514
#    Métrica Combinada: 0.7034
#    Modelo salvo: ../results/baseline/RAF-DB/models/resnet50_best.pth
# Early Stopping: Melhoria detectada (0.7034, Delta=+0.0497)
#
# Época [3/100] - Tempo: 32.82s
#    Train Loss: 0.3248
#    Val Acc: 0.7445 | Val F1: 0.6460
#    Val Precision: 0.6549 | Val Recall: 0.6459
#    Métrica Combinada: 0.6854
# Early Stopping: Sem melhoria (1/15)
#
# Época [4/100] - Tempo: 32.64s
#    Train Loss: 0.1674
#    Val Acc: 0.7383 | Val F1: 0.6249
#    Val Precision: 0.6642 | Val Recall: 0.6053
#    Métrica Combinada: 0.6702
# Early Stopping: Sem melhoria (2/15)
#
# Época [5/100] - Tempo: 32.53s
#    Train Loss: 0.0989
#    Val Acc: 0.7614 | Val F1: 0.6609
#    Val Precision: 0.6813 | Val Recall: 0.6469
#    Métrica Combinada: 0.7011
# Early Stopping: Sem melhoria (3/15)
#
# Época [6/100] - Tempo: 32.57s
#    Train Loss: 0.0915
#    Val Acc: 0.7389 | Val F1: 0.6419
#    Val Precision: 0.6673 | Val Recall: 0.6319
#    Métrica Combinada: 0.6807
# Early Stopping: Sem melhoria (4/15)
#
# Época [7/100] - Tempo: 32.59s
#    Train Loss: 0.0692
#    Val Acc: 0.7451 | Val F1: 0.6467
#    Val Precision: 0.6681 | Val Recall: 0.6359
#    Métrica Combinada: 0.6861
# Early Stopping: Sem melhoria (5/15)
#
# Época [8/100] - Tempo: 32.58s
#    Train Loss: 0.0759
#    Val Acc: 0.7448 | Val F1: 0.6428
#    Val Precision: 0.6486 | Val Recall: 0.6542
#    Métrica Combinada: 0.6836
# Early Stopping: Sem melhoria (6/15)
#
# Época [9/100] - Tempo: 32.59s
#    Train Loss: 0.0363
#    Val Acc: 0.7676 | Val F1: 0.6748
#    Val Precision: 0.7161 | Val Recall: 0.6513
#    Métrica Combinada: 0.7119
#    Modelo salvo: ../results/baseline/RAF-DB/models/resnet50_best.pth
# Early Stopping: Melhoria detectada (0.7119, Delta=+0.0085)
#
# Época [10/100] - Tempo: 32.53s
#    Train Loss: 0.0507
#    Val Acc: 0.7419 | Val F1: 0.6335
#    Val Precision: 0.6229 | Val Recall: 0.6547
#    Métrica Combinada: 0.6769
# Early Stopping: Sem melhoria (1/15)
#
# Época [11/100] - Tempo: 32.54s
#    Train Loss: 0.0472
#    Val Acc: 0.7536 | Val F1: 0.6681
#    Val Precision: 0.6854 | Val Recall: 0.6595
#    Métrica Combinada: 0.7023
# Early Stopping: Sem melhoria (2/15)
#
# Época [12/100] - Tempo: 32.52s
#    Train Loss: 0.0532
#    Val Acc: 0.7568 | Val F1: 0.6562
#    Val Precision: 0.6839 | Val Recall: 0.6427
#    Métrica Combinada: 0.6965
# Early Stopping: Sem melhoria (3/15)
#
# Época [13/100] - Tempo: 32.53s
#    Train Loss: 0.0493
#    Val Acc: 0.7748 | Val F1: 0.6847
#    Val Precision: 0.7217 | Val Recall: 0.6656
#    Métrica Combinada: 0.7208
#    Modelo salvo: ../results/baseline/RAF-DB/models/resnet50_best.pth
# Early Stopping: Melhoria detectada (0.7208, Delta=+0.0088)
#
# Época [14/100] - Tempo: 32.52s
#    Train Loss: 0.0287
#    Val Acc: 0.7467 | Val F1: 0.6533
#    Val Precision: 0.6600 | Val Recall: 0.6562
#    Métrica Combinada: 0.6907
# Early Stopping: Sem melhoria (1/15)
#
# Época [15/100] - Tempo: 32.54s
#    Train Loss: 0.0364
#    Val Acc: 0.7627 | Val F1: 0.6451
#    Val Precision: 0.7090 | Val Recall: 0.6343
#    Métrica Combinada: 0.6922
# Early Stopping: Sem melhoria (2/15)
#
# Época [16/100] - Tempo: 32.53s
#    Train Loss: 0.0226
#    Val Acc: 0.7696 | Val F1: 0.6609
#    Val Precision: 0.7060 | Val Recall: 0.6388
#    Métrica Combinada: 0.7044
# Early Stopping: Sem melhoria (3/15)
#
# Época [17/100] - Tempo: 32.53s
#    Train Loss: 0.0340
#    Val Acc: 0.7601 | Val F1: 0.6761
#    Val Precision: 0.7126 | Val Recall: 0.6532
#    Métrica Combinada: 0.7097
# Early Stopping: Sem melhoria (4/15)
#
# Época [18/100] - Tempo: 32.55s
#    Train Loss: 0.0477
#    Val Acc: 0.7477 | Val F1: 0.6255
#    Val Precision: 0.6642 | Val Recall: 0.6083
#    Métrica Combinada: 0.6744
# Early Stopping: Sem melhoria (5/15)
#
# Época [19/100] - Tempo: 32.54s
#    Train Loss: 0.0502
#    Val Acc: 0.7611 | Val F1: 0.6599
#    Val Precision: 0.6858 | Val Recall: 0.6466
#    Métrica Combinada: 0.7004
# Early Stopping: Sem melhoria (6/15)
#
# Época [20/100] - Tempo: 32.56s
#    Train Loss: 0.0245
#    Val Acc: 0.7696 | Val F1: 0.6699
#    Val Precision: 0.6986 | Val Recall: 0.6547
#    Métrica Combinada: 0.7098
# Early Stopping: Sem melhoria (7/15)
#
# Época [21/100] - Tempo: 32.53s
#    Train Loss: 0.0353
#    Val Acc: 0.7575 | Val F1: 0.6715
#    Val Precision: 0.6824 | Val Recall: 0.6656
#    Métrica Combinada: 0.7059
# Early Stopping: Sem melhoria (8/15)
#
# Época [22/100] - Tempo: 32.62s
#    Train Loss: 0.0366
#    Val Acc: 0.7474 | Val F1: 0.6296
#    Val Precision: 0.7278 | Val Recall: 0.6010
#    Métrica Combinada: 0.6767
# Early Stopping: Sem melhoria (9/15)
#
# Época [23/100] - Tempo: 32.52s
#    Train Loss: 0.0331
#    Val Acc: 0.7422 | Val F1: 0.6466
#    Val Precision: 0.6514 | Val Recall: 0.6568
#    Métrica Combinada: 0.6849
# Early Stopping: Sem melhoria (10/15)
#
# Época [24/100] - Tempo: 32.53s
#    Train Loss: 0.0282
#    Val Acc: 0.7647 | Val F1: 0.6662
#    Val Precision: 0.7070 | Val Recall: 0.6463
#    Métrica Combinada: 0.7056
# Early Stopping: Sem melhoria (11/15)
#
# Época [25/100] - Tempo: 32.52s
#    Train Loss: 0.0128
#    Val Acc: 0.7754 | Val F1: 0.6911
#    Val Precision: 0.7283 | Val Recall: 0.6671
#    Métrica Combinada: 0.7249
#    Modelo salvo: ../results/baseline/RAF-DB/models/resnet50_best.pth
# Early Stopping: Melhoria detectada (0.7249, Delta=+0.0041)
#
# Época [26/100] - Tempo: 32.53s
#    Train Loss: 0.0096
#    Val Acc: 0.7741 | Val F1: 0.6764
#    Val Precision: 0.7209 | Val Recall: 0.6549
#    Métrica Combinada: 0.7155
# Early Stopping: Sem melhoria (1/15)
#
# Época [27/100] - Tempo: 32.53s
#    Train Loss: 0.0211
#    Val Acc: 0.7448 | Val F1: 0.6481
#    Val Precision: 0.6935 | Val Recall: 0.6223
#    Métrica Combinada: 0.6868
# Early Stopping: Sem melhoria (2/15)
#
# Época [28/100] - Tempo: 32.53s
#    Train Loss: 0.0533
#    Val Acc: 0.7471 | Val F1: 0.6378
#    Val Precision: 0.6680 | Val Recall: 0.6320
#    Métrica Combinada: 0.6815
# Early Stopping: Sem melhoria (3/15)
#
# Época [29/100] - Tempo: 32.57s
#    Train Loss: 0.0475
#    Val Acc: 0.7699 | Val F1: 0.6682
#    Val Precision: 0.6883 | Val Recall: 0.6575
#    Métrica Combinada: 0.7089
# Early Stopping: Sem melhoria (4/15)
#
# Época [30/100] - Tempo: 32.73s
#    Train Loss: 0.0161
#    Val Acc: 0.7757 | Val F1: 0.6709
#    Val Precision: 0.7311 | Val Recall: 0.6463
#    Métrica Combinada: 0.7129
# Early Stopping: Sem melhoria (5/15)
#
# Época [31/100] - Tempo: 32.56s
#    Train Loss: 0.0063
#    Val Acc: 0.7832 | Val F1: 0.6886
#    Val Precision: 0.7230 | Val Recall: 0.6664
#    Métrica Combinada: 0.7264
#    Modelo salvo: ../results/baseline/RAF-DB/models/resnet50_best.pth
# Early Stopping: Melhoria detectada (0.7264, Delta=+0.0016)
#
# Época [32/100] - Tempo: 32.54s
#    Train Loss: 0.0037
#    Val Acc: 0.7803 | Val F1: 0.6824
#    Val Precision: 0.7124 | Val Recall: 0.6635
#    Métrica Combinada: 0.7216
# Early Stopping: Sem melhoria (1/15)
#
# Época [33/100] - Tempo: 32.54s
#    Train Loss: 0.0045
#    Val Acc: 0.7679 | Val F1: 0.6659
#    Val Precision: 0.6919 | Val Recall: 0.6653
#    Métrica Combinada: 0.7067
# Early Stopping: Sem melhoria (2/15)
#
# Época [34/100] - Tempo: 32.55s
#    Train Loss: 0.0329
#    Val Acc: 0.6943 | Val F1: 0.5864
#    Val Precision: 0.5730 | Val Recall: 0.6301
#    Métrica Combinada: 0.6295
# Early Stopping: Sem melhoria (3/15)
#
# Época [35/100] - Tempo: 32.57s
#    Train Loss: 0.0770
#    Val Acc: 0.7353 | Val F1: 0.6258
#    Val Precision: 0.7066 | Val Recall: 0.6118
#    Métrica Combinada: 0.6696
# Early Stopping: Sem melhoria (4/15)
#
# Época [36/100] - Tempo: 32.56s
#    Train Loss: 0.0282
#    Val Acc: 0.7663 | Val F1: 0.6583
#    Val Precision: 0.6961 | Val Recall: 0.6385
#    Métrica Combinada: 0.7015
# Early Stopping: Sem melhoria (5/15)
#
# Época [37/100] - Tempo: 32.57s
#    Train Loss: 0.0141
#    Val Acc: 0.7653 | Val F1: 0.6684
#    Val Precision: 0.7158 | Val Recall: 0.6485
#    Métrica Combinada: 0.7072
# Early Stopping: Sem melhoria (6/15)
#
# Época [38/100] - Tempo: 32.55s
#    Train Loss: 0.0076
#    Val Acc: 0.7709 | Val F1: 0.6652
#    Val Precision: 0.6964 | Val Recall: 0.6583
#    Métrica Combinada: 0.7074
# Early Stopping: Sem melhoria (7/15)
#
# Época [39/100] - Tempo: 32.54s
#    Train Loss: 0.0052
#    Val Acc: 0.7660 | Val F1: 0.6792
#    Val Precision: 0.6890 | Val Recall: 0.6738
#    Métrica Combinada: 0.7139
# Early Stopping: Sem melhoria (8/15)
#
# Época [40/100] - Tempo: 32.59s
#    Train Loss: 0.0145
#    Val Acc: 0.7565 | Val F1: 0.6507
#    Val Precision: 0.6981 | Val Recall: 0.6210
#    Métrica Combinada: 0.6930
# Early Stopping: Sem melhoria (9/15)
#
# Época [41/100] - Tempo: 32.57s
#    Train Loss: 0.0389
#    Val Acc: 0.7559 | Val F1: 0.6342
#    Val Precision: 0.6938 | Val Recall: 0.6073
#    Métrica Combinada: 0.6829
# Early Stopping: Sem melhoria (10/15)
#
# Época [42/100] - Tempo: 32.58s
#    Train Loss: 0.0325
#    Val Acc: 0.7568 | Val F1: 0.6550
#    Val Precision: 0.6888 | Val Recall: 0.6325
#    Métrica Combinada: 0.6957
# Early Stopping: Sem melhoria (11/15)
#
# Época [43/100] - Tempo: 32.55s
#    Train Loss: 0.0426
#    Val Acc: 0.7624 | Val F1: 0.6611
#    Val Precision: 0.6864 | Val Recall: 0.6440
#    Métrica Combinada: 0.7016
# Early Stopping: Sem melhoria (12/15)
#
# Época [44/100] - Tempo: 32.54s
#    Train Loss: 0.0228
#    Val Acc: 0.7683 | Val F1: 0.6758
#    Val Precision: 0.7023 | Val Recall: 0.6603
#    Métrica Combinada: 0.7128
# Early Stopping: Sem melhoria (13/15)
#
# Época [45/100] - Tempo: 32.55s
#    Train Loss: 0.0165
#    Val Acc: 0.7702 | Val F1: 0.6736
#    Val Precision: 0.6958 | Val Recall: 0.6611
#    Métrica Combinada: 0.7123
# Early Stopping: Sem melhoria (14/15)
#
# Época [46/100] - Tempo: 32.54s
#    Train Loss: 0.0054
#    Val Acc: 0.7741 | Val F1: 0.6830
#    Val Precision: 0.7139 | Val Recall: 0.6622
#    Métrica Combinada: 0.7195
# Early Stopping: Sem melhoria (15/15)
# Early Stopping: Treinamento interrompido após 15 épocas sem melhoria
#
# Early stopping ativado na época 46
#
# ======================================================================
# MONITORING REPORT: RESNET50
# ======================================================================
# Total training time: 0:25:00
# Initial RAM: 730.14 MB
# Final RAM: 1377.11 MB
# Peak RAM: 1377.13 MB
# Memory increase: 646.97 MB
# Peak GPU Memory: 3121.62 MB
# Final GPU Memory: 385.08 MB
# ======================================================================
#
# Avaliando modelo no conjunto de teste...
# Testando: 100%|██████████| 48/48 [00:02<00:00, 18.77it/s]
# ======================================================================
# RESULTADOS DA AVALIAÇÃO - CONJUNTO DE TESTE
# ======================================================================
# Acurácia: 0.7832
#
# Métricas Macro:
#    Precisão: 0.7230
#    Recall: 0.6664
#    F1-Score: 0.6886
#
# F1-Score Weighted: 0.7801
# ======================================================================
#
#
# Métricas por Classe:
# Classe          Precisão     Recall       F1-Score     Suporte
# ----------------------------------------------------------------------
# Raiva           0.7402       0.5802       0.6505       162
# Nojo            0.5141       0.4562       0.4834       160
# Medo            0.6957       0.4324       0.5333       74
# Felicidade      0.8778       0.9030       0.8902       1185
# Neutro          0.7309       0.7750       0.7523       680
# Tristeza        0.7248       0.7218       0.7233       478
# Surpresa        0.7774       0.7964       0.7868       329
# ----------------------------------------------------------------------
# Métricas salvas: ../results/baseline/RAF-DB/metrics/resnet50_metrics_20251031_171731.json
# Matrizes de confusão salvas: ../results/baseline/RAF-DB/plots/resnet50_confusion_20251031_171731.png
# Histórico de treinamento salvo: ../results/baseline/RAF-DB/plots/resnet50_history_20251031_171731.png
#
# Todos os resultados salvos para resnet50
#
# ================================================================================
# TREINANDO: EFFICIENTNET_B0
# ================================================================================
#
# 🔍 Iniciando monitoramento: efficientnet_b0
#   • Initial RAM: 1440.93 MB
#   • Initial GPU: 16.25 MB
# Modelo 'efficientnet_b0' criado com sucesso
#    Total de parâmetros: 4,015,939
#    Parâmetros treináveis: 4,015,939
#
# Época [1/100] - Tempo: 19.57s
#    Train Loss: 1.3665
#    Val Acc: 0.6353 | Val F1: 0.4109
#    Val Precision: 0.4460 | Val Recall: 0.4169
#    Métrica Combinada: 0.5006
#    Modelo salvo: ../results/baseline/RAF-DB/models/efficientnet_b0_best.pth
# Early Stopping: Baseline estabelecida: 0.5006
#
# Época [2/100] - Tempo: 19.40s
#    Train Loss: 0.9104
#    Val Acc: 0.6992 | Val F1: 0.5472
#    Val Precision: 0.6716 | Val Recall: 0.5216
#    Métrica Combinada: 0.6080
#    Modelo salvo: ../results/baseline/RAF-DB/models/efficientnet_b0_best.pth
# Early Stopping: Melhoria detectada (0.6080, Delta=+0.1073)
#
# Época [3/100] - Tempo: 19.41s
#    Train Loss: 0.6863
#    Val Acc: 0.7154 | Val F1: 0.5908
#    Val Precision: 0.6640 | Val Recall: 0.5631
#    Métrica Combinada: 0.6407
#    Modelo salvo: ../results/baseline/RAF-DB/models/efficientnet_b0_best.pth
# Early Stopping: Melhoria detectada (0.6407, Delta=+0.0327)
#
# Época [4/100] - Tempo: 19.42s
#    Train Loss: 0.5358
#    Val Acc: 0.7337 | Val F1: 0.6213
#    Val Precision: 0.6612 | Val Recall: 0.6037
#    Métrica Combinada: 0.6663
#    Modelo salvo: ../results/baseline/RAF-DB/models/efficientnet_b0_best.pth
# Early Stopping: Melhoria detectada (0.6663, Delta=+0.0256)
#
# Época [5/100] - Tempo: 19.51s
#    Train Loss: 0.4077
#    Val Acc: 0.7392 | Val F1: 0.6244
#    Val Precision: 0.6661 | Val Recall: 0.6051
#    Métrica Combinada: 0.6704
#    Modelo salvo: ../results/baseline/RAF-DB/models/efficientnet_b0_best.pth
# Early Stopping: Melhoria detectada (0.6704, Delta=+0.0041)
#
# Época [6/100] - Tempo: 19.52s
#    Train Loss: 0.2960
#    Val Acc: 0.7490 | Val F1: 0.6439
#    Val Precision: 0.6795 | Val Recall: 0.6230
#    Métrica Combinada: 0.6860
#    Modelo salvo: ../results/baseline/RAF-DB/models/efficientnet_b0_best.pth
# Early Stopping: Melhoria detectada (0.6860, Delta=+0.0156)
#
# Época [7/100] - Tempo: 19.53s
#    Train Loss: 0.2302
#    Val Acc: 0.7405 | Val F1: 0.6331
#    Val Precision: 0.6619 | Val Recall: 0.6222
#    Métrica Combinada: 0.6761
# Early Stopping: Sem melhoria (1/15)
#
# Época [8/100] - Tempo: 19.52s
#    Train Loss: 0.1817
#    Val Acc: 0.7422 | Val F1: 0.6343
#    Val Precision: 0.6430 | Val Recall: 0.6288
#    Métrica Combinada: 0.6775
# Early Stopping: Sem melhoria (2/15)
#
# Época [9/100] - Tempo: 19.53s
#    Train Loss: 0.1469
#    Val Acc: 0.7451 | Val F1: 0.6384
#    Val Precision: 0.6475 | Val Recall: 0.6313
#    Métrica Combinada: 0.6811
# Early Stopping: Sem melhoria (3/15)
#
# Época [10/100] - Tempo: 19.52s
#    Train Loss: 0.1180
#    Val Acc: 0.7425 | Val F1: 0.6314
#    Val Precision: 0.6702 | Val Recall: 0.6089
#    Métrica Combinada: 0.6758
# Early Stopping: Sem melhoria (4/15)
#
# Época [11/100] - Tempo: 19.54s
#    Train Loss: 0.1034
#    Val Acc: 0.7438 | Val F1: 0.6383
#    Val Precision: 0.6581 | Val Recall: 0.6256
#    Métrica Combinada: 0.6805
# Early Stopping: Sem melhoria (5/15)
#
# Época [12/100] - Tempo: 19.54s
#    Train Loss: 0.0909
#    Val Acc: 0.7474 | Val F1: 0.6355
#    Val Precision: 0.6588 | Val Recall: 0.6195
#    Métrica Combinada: 0.6802
# Early Stopping: Sem melhoria (6/15)
#
# Época [13/100] - Tempo: 19.53s
#    Train Loss: 0.0846
#    Val Acc: 0.7467 | Val F1: 0.6450
#    Val Precision: 0.6833 | Val Recall: 0.6226
#    Métrica Combinada: 0.6857
# Early Stopping: Sem melhoria (7/15)
#
# Época [14/100] - Tempo: 19.53s
#    Train Loss: 0.0746
#    Val Acc: 0.7474 | Val F1: 0.6368
#    Val Precision: 0.6588 | Val Recall: 0.6209
#    Métrica Combinada: 0.6810
# Early Stopping: Sem melhoria (8/15)
#
# Época [15/100] - Tempo: 19.51s
#    Train Loss: 0.0658
#    Val Acc: 0.7467 | Val F1: 0.6350
#    Val Precision: 0.6451 | Val Recall: 0.6271
#    Métrica Combinada: 0.6797
# Early Stopping: Sem melhoria (9/15)
#
# Época [16/100] - Tempo: 19.55s
#    Train Loss: 0.0599
#    Val Acc: 0.7445 | Val F1: 0.6384
#    Val Precision: 0.6623 | Val Recall: 0.6275
#    Métrica Combinada: 0.6808
# Early Stopping: Sem melhoria (10/15)
#
# Época [17/100] - Tempo: 19.54s
#    Train Loss: 0.0611
#    Val Acc: 0.7454 | Val F1: 0.6447
#    Val Precision: 0.6621 | Val Recall: 0.6362
#    Métrica Combinada: 0.6850
# Early Stopping: Sem melhoria (11/15)
#
# Época [18/100] - Tempo: 19.51s
#    Train Loss: 0.0554
#    Val Acc: 0.7552 | Val F1: 0.6439
#    Val Precision: 0.6754 | Val Recall: 0.6282
#    Métrica Combinada: 0.6884
#    Modelo salvo: ../results/baseline/RAF-DB/models/efficientnet_b0_best.pth
# Early Stopping: Melhoria detectada (0.6884, Delta=+0.0025)
#
# Época [19/100] - Tempo: 19.50s
#    Train Loss: 0.0512
#    Val Acc: 0.7552 | Val F1: 0.6548
#    Val Precision: 0.6859 | Val Recall: 0.6354
#    Métrica Combinada: 0.6950
#    Modelo salvo: ../results/baseline/RAF-DB/models/efficientnet_b0_best.pth
# Early Stopping: Melhoria detectada (0.6950, Delta=+0.0065)
#
# Época [20/100] - Tempo: 19.41s
#    Train Loss: 0.0496
#    Val Acc: 0.7497 | Val F1: 0.6410
#    Val Precision: 0.6681 | Val Recall: 0.6247
#    Métrica Combinada: 0.6845
# Early Stopping: Sem melhoria (1/15)
#
# Época [21/100] - Tempo: 19.41s
#    Train Loss: 0.0500
#    Val Acc: 0.7549 | Val F1: 0.6614
#    Val Precision: 0.6889 | Val Recall: 0.6440
#    Métrica Combinada: 0.6988
#    Modelo salvo: ../results/baseline/RAF-DB/models/efficientnet_b0_best.pth
# Early Stopping: Melhoria detectada (0.6988, Delta=+0.0038)
#
# Época [22/100] - Tempo: 19.41s
#    Train Loss: 0.0394
#    Val Acc: 0.7598 | Val F1: 0.6613
#    Val Precision: 0.6868 | Val Recall: 0.6460
#    Métrica Combinada: 0.7007
#    Modelo salvo: ../results/baseline/RAF-DB/models/efficientnet_b0_best.pth
# Early Stopping: Melhoria detectada (0.7007, Delta=+0.0019)
#
# Época [23/100] - Tempo: 19.40s
#    Train Loss: 0.0394
#    Val Acc: 0.7448 | Val F1: 0.6341
#    Val Precision: 0.6539 | Val Recall: 0.6210
#    Métrica Combinada: 0.6784
# Early Stopping: Sem melhoria (1/15)
#
# Época [24/100] - Tempo: 19.41s
#    Train Loss: 0.0383
#    Val Acc: 0.7546 | Val F1: 0.6459
#    Val Precision: 0.6698 | Val Recall: 0.6310
#    Métrica Combinada: 0.6893
# Early Stopping: Sem melhoria (2/15)
#
# Época [25/100] - Tempo: 19.42s
#    Train Loss: 0.0421
#    Val Acc: 0.7441 | Val F1: 0.6388
#    Val Precision: 0.6573 | Val Recall: 0.6262
#    Métrica Combinada: 0.6809
# Early Stopping: Sem melhoria (3/15)
#
# Época [26/100] - Tempo: 19.42s
#    Train Loss: 0.0358
#    Val Acc: 0.7526 | Val F1: 0.6536
#    Val Precision: 0.6694 | Val Recall: 0.6423
#    Métrica Combinada: 0.6932
# Early Stopping: Sem melhoria (4/15)
#
# Época [27/100] - Tempo: 19.42s
#    Train Loss: 0.0318
#    Val Acc: 0.7471 | Val F1: 0.6500
#    Val Precision: 0.6839 | Val Recall: 0.6302
#    Métrica Combinada: 0.6888
# Early Stopping: Sem melhoria (5/15)
#
# Época [28/100] - Tempo: 19.43s
#    Train Loss: 0.0349
#    Val Acc: 0.7575 | Val F1: 0.6661
#    Val Precision: 0.7031 | Val Recall: 0.6450
#    Métrica Combinada: 0.7027
#    Modelo salvo: ../results/baseline/RAF-DB/models/efficientnet_b0_best.pth
# Early Stopping: Melhoria detectada (0.7027, Delta=+0.0020)
#
# Época [29/100] - Tempo: 19.43s
#    Train Loss: 0.0288
#    Val Acc: 0.7575 | Val F1: 0.6553
#    Val Precision: 0.6919 | Val Recall: 0.6377
#    Métrica Combinada: 0.6961
# Early Stopping: Sem melhoria (1/15)
#
# Época [30/100] - Tempo: 19.41s
#    Train Loss: 0.0310
#    Val Acc: 0.7536 | Val F1: 0.6498
#    Val Precision: 0.6849 | Val Recall: 0.6272
#    Métrica Combinada: 0.6913
# Early Stopping: Sem melhoria (2/15)
#
# Época [31/100] - Tempo: 19.42s
#    Train Loss: 0.0329
#    Val Acc: 0.7585 | Val F1: 0.6562
#    Val Precision: 0.6900 | Val Recall: 0.6367
#    Métrica Combinada: 0.6971
# Early Stopping: Sem melhoria (3/15)
#
# Época [32/100] - Tempo: 19.43s
#    Train Loss: 0.0360
#    Val Acc: 0.7614 | Val F1: 0.6558
#    Val Precision: 0.6907 | Val Recall: 0.6353
#    Métrica Combinada: 0.6980
# Early Stopping: Sem melhoria (4/15)
#
# Época [33/100] - Tempo: 19.42s
#    Train Loss: 0.0374
#    Val Acc: 0.7526 | Val F1: 0.6543
#    Val Precision: 0.7019 | Val Recall: 0.6317
#    Métrica Combinada: 0.6936
# Early Stopping: Sem melhoria (5/15)
#
# Época [34/100] - Tempo: 19.41s
#    Train Loss: 0.0298
#    Val Acc: 0.7585 | Val F1: 0.6473
#    Val Precision: 0.6694 | Val Recall: 0.6350
#    Métrica Combinada: 0.6918
# Early Stopping: Sem melhoria (6/15)
#
# Época [35/100] - Tempo: 19.42s
#    Train Loss: 0.0304
#    Val Acc: 0.7549 | Val F1: 0.6431
#    Val Precision: 0.6842 | Val Recall: 0.6182
#    Métrica Combinada: 0.6878
# Early Stopping: Sem melhoria (7/15)
#
# Época [36/100] - Tempo: 19.42s
#    Train Loss: 0.0321
#    Val Acc: 0.7529 | Val F1: 0.6467
#    Val Precision: 0.6654 | Val Recall: 0.6349
#    Métrica Combinada: 0.6892
# Early Stopping: Sem melhoria (8/15)
#
# Época [37/100] - Tempo: 19.42s
#    Train Loss: 0.0271
#    Val Acc: 0.7555 | Val F1: 0.6582
#    Val Precision: 0.6982 | Val Recall: 0.6404
#    Métrica Combinada: 0.6971
# Early Stopping: Sem melhoria (9/15)
#
# Época [38/100] - Tempo: 19.43s
#    Train Loss: 0.0293
#    Val Acc: 0.7510 | Val F1: 0.6412
#    Val Precision: 0.6822 | Val Recall: 0.6192
#    Métrica Combinada: 0.6851
# Early Stopping: Sem melhoria (10/15)
#
# Época [39/100] - Tempo: 19.43s
#    Train Loss: 0.0243
#    Val Acc: 0.7588 | Val F1: 0.6594
#    Val Precision: 0.6955 | Val Recall: 0.6412
#    Métrica Combinada: 0.6992
# Early Stopping: Sem melhoria (11/15)
#
# Época [40/100] - Tempo: 19.42s
#    Train Loss: 0.0251
#    Val Acc: 0.7617 | Val F1: 0.6586
#    Val Precision: 0.6869 | Val Recall: 0.6415
#    Métrica Combinada: 0.6998
# Early Stopping: Sem melhoria (12/15)
#
# Época [41/100] - Tempo: 19.40s
#    Train Loss: 0.0284
#    Val Acc: 0.7614 | Val F1: 0.6635
#    Val Precision: 0.6887 | Val Recall: 0.6503
#    Métrica Combinada: 0.7026
# Early Stopping: Sem melhoria (13/15)
#
# Época [42/100] - Tempo: 19.41s
#    Train Loss: 0.0230
#    Val Acc: 0.7604 | Val F1: 0.6628
#    Val Precision: 0.6963 | Val Recall: 0.6441
#    Métrica Combinada: 0.7018
# Early Stopping: Sem melhoria (14/15)
#
# Época [43/100] - Tempo: 19.42s
#    Train Loss: 0.0260
#    Val Acc: 0.7578 | Val F1: 0.6565
#    Val Precision: 0.6726 | Val Recall: 0.6459
#    Métrica Combinada: 0.6971
# Early Stopping: Sem melhoria (15/15)
# Early Stopping: Treinamento interrompido após 15 épocas sem melhoria
#
# Early stopping ativado na época 43
#
# ======================================================================
# MONITORING REPORT: EFFICIENTNET_B0
# ======================================================================
# Total training time: 0:13:58
# Initial RAM: 1440.93 MB
# Final RAM: 1521.98 MB
# Peak RAM: 1522.02 MB
# Memory increase: 81.05 MB
# Peak GPU Memory: 3121.62 MB
# Final GPU Memory: 79.44 MB
# ======================================================================
#
# Avaliando modelo no conjunto de teste...
# Testando: 100%|██████████| 48/48 [00:01<00:00, 36.08it/s]
# ======================================================================
# RESULTADOS DA AVALIAÇÃO - CONJUNTO DE TESTE
# ======================================================================
# Acurácia: 0.7575
#
# Métricas Macro:
#    Precisão: 0.7031
#    Recall: 0.6450
#    F1-Score: 0.6661
#
# F1-Score Weighted: 0.7555
# ======================================================================
#
#
# Métricas por Classe:
# Classe          Precisão     Recall       F1-Score     Suporte
# ----------------------------------------------------------------------
# Raiva           0.6710       0.6420       0.6562       162
# Nojo            0.4241       0.4188       0.4214       160
# Medo            0.7805       0.4324       0.5565       74
# Felicidade      0.8575       0.8886       0.8728       1185
# Neutro          0.7165       0.7397       0.7279       680
# Tristeza        0.6813       0.7155       0.6980       478
# Surpresa        0.7908       0.6778       0.7300       329
# ----------------------------------------------------------------------
# Métricas salvas: ../results/baseline/RAF-DB/metrics/efficientnet_b0_metrics_20251031_173133.json
# Matrizes de confusão salvas: ../results/baseline/RAF-DB/plots/efficientnet_b0_confusion_20251031_173133.png
# Histórico de treinamento salvo: ../results/baseline/RAF-DB/plots/efficientnet_b0_history_20251031_173133.png
#
# Todos os resultados salvos para efficientnet_b0
#
# ================================================================================
# TREINANDO: EFFICIENTVIT_M5
# ================================================================================
#
# 🔍 Iniciando monitoramento: efficientvit_m5
#   • Initial RAM: 1589.21 MB
#   • Initial GPU: 16.25 MB
# Modelo 'efficientvit_m5' criado com sucesso
#    Total de parâmetros: 12,091,035
#    Parâmetros treináveis: 12,091,035
#
# Época [1/100] - Tempo: 15.27s
#    Train Loss: 1.8583
#    Val Acc: 0.4469 | Val F1: 0.2778
#    Val Precision: 0.2901 | Val Recall: 0.2817
#    Métrica Combinada: 0.3454
#    Modelo salvo: ../results/baseline/RAF-DB/models/efficientvit_m5_best.pth
# Early Stopping: Baseline estabelecida: 0.3454
#
# Época [2/100] - Tempo: 14.94s
#    Train Loss: 1.5388
#    Val Acc: 0.5417 | Val F1: 0.3237
#    Val Precision: 0.3756 | Val Recall: 0.3272
#    Métrica Combinada: 0.4109
#    Modelo salvo: ../results/baseline/RAF-DB/models/efficientvit_m5_best.pth
# Early Stopping: Melhoria detectada (0.4109, Delta=+0.0654)
#
# Época [3/100] - Tempo: 15.16s
#    Train Loss: 1.2096
#    Val Acc: 0.5965 | Val F1: 0.3982
#    Val Precision: 0.4825 | Val Recall: 0.3894
#    Métrica Combinada: 0.4775
#    Modelo salvo: ../results/baseline/RAF-DB/models/efficientvit_m5_best.pth
# Early Stopping: Melhoria detectada (0.4775, Delta=+0.0666)
#
# Época [4/100] - Tempo: 15.08s
#    Train Loss: 0.9798
#    Val Acc: 0.6304 | Val F1: 0.4301
#    Val Precision: 0.5559 | Val Recall: 0.4334
#    Métrica Combinada: 0.5102
#    Modelo salvo: ../results/baseline/RAF-DB/models/efficientvit_m5_best.pth
# Early Stopping: Melhoria detectada (0.5102, Delta=+0.0327)
#
# Época [5/100] - Tempo: 14.99s
#    Train Loss: 0.8025
#    Val Acc: 0.6372 | Val F1: 0.4580
#    Val Precision: 0.5916 | Val Recall: 0.4442
#    Métrica Combinada: 0.5297
#    Modelo salvo: ../results/baseline/RAF-DB/models/efficientvit_m5_best.pth
# Early Stopping: Melhoria detectada (0.5297, Delta=+0.0195)
#
# Época [6/100] - Tempo: 14.92s
#    Train Loss: 0.6657
#    Val Acc: 0.6561 | Val F1: 0.5118
#    Val Precision: 0.5915 | Val Recall: 0.4936
#    Métrica Combinada: 0.5695
#    Modelo salvo: ../results/baseline/RAF-DB/models/efficientvit_m5_best.pth
# Early Stopping: Melhoria detectada (0.5695, Delta=+0.0398)
#
# Época [7/100] - Tempo: 15.02s
#    Train Loss: 0.4978
#    Val Acc: 0.6561 | Val F1: 0.5232
#    Val Precision: 0.5930 | Val Recall: 0.4949
#    Métrica Combinada: 0.5764
#    Modelo salvo: ../results/baseline/RAF-DB/models/efficientvit_m5_best.pth
# Early Stopping: Melhoria detectada (0.5764, Delta=+0.0069)
#
# Época [8/100] - Tempo: 15.13s
#    Train Loss: 0.3810
#    Val Acc: 0.6558 | Val F1: 0.5322
#    Val Precision: 0.5673 | Val Recall: 0.5113
#    Métrica Combinada: 0.5816
#    Modelo salvo: ../results/baseline/RAF-DB/models/efficientvit_m5_best.pth
# Early Stopping: Melhoria detectada (0.5816, Delta=+0.0053)
#
# Época [9/100] - Tempo: 15.28s
#    Train Loss: 0.3001
#    Val Acc: 0.6620 | Val F1: 0.5452
#    Val Precision: 0.5809 | Val Recall: 0.5279
#    Métrica Combinada: 0.5919
#    Modelo salvo: ../results/baseline/RAF-DB/models/efficientvit_m5_best.pth
# Early Stopping: Melhoria detectada (0.5919, Delta=+0.0103)
#
# Época [10/100] - Tempo: 14.90s
#    Train Loss: 0.2007
#    Val Acc: 0.6672 | Val F1: 0.5555
#    Val Precision: 0.5799 | Val Recall: 0.5429
#    Métrica Combinada: 0.6002
#    Modelo salvo: ../results/baseline/RAF-DB/models/efficientvit_m5_best.pth
# Early Stopping: Melhoria detectada (0.6002, Delta=+0.0083)
#
# Época [11/100] - Tempo: 14.97s
#    Train Loss: 0.1456
#    Val Acc: 0.6630 | Val F1: 0.5438
#    Val Precision: 0.5669 | Val Recall: 0.5283
#    Métrica Combinada: 0.5915
# Early Stopping: Sem melhoria (1/15)
#
# Época [12/100] - Tempo: 15.05s
#    Train Loss: 0.1129
#    Val Acc: 0.6685 | Val F1: 0.5502
#    Val Precision: 0.5744 | Val Recall: 0.5354
#    Métrica Combinada: 0.5975
# Early Stopping: Sem melhoria (2/15)
#
# Época [13/100] - Tempo: 15.07s
#    Train Loss: 0.0978
#    Val Acc: 0.6571 | Val F1: 0.5394
#    Val Precision: 0.5628 | Val Recall: 0.5260
#    Métrica Combinada: 0.5865
# Early Stopping: Sem melhoria (3/15)
#
# Época [14/100] - Tempo: 14.94s
#    Train Loss: 0.0736
#    Val Acc: 0.6643 | Val F1: 0.5431
#    Val Precision: 0.5760 | Val Recall: 0.5230
#    Métrica Combinada: 0.5915
# Early Stopping: Sem melhoria (4/15)
#
# Época [15/100] - Tempo: 15.14s
#    Train Loss: 0.0522
#    Val Acc: 0.6675 | Val F1: 0.5491
#    Val Precision: 0.5740 | Val Recall: 0.5343
#    Métrica Combinada: 0.5965
# Early Stopping: Sem melhoria (5/15)
#
# Época [16/100] - Tempo: 14.94s
#    Train Loss: 0.0535
#    Val Acc: 0.6757 | Val F1: 0.5588
#    Val Precision: 0.5892 | Val Recall: 0.5419
#    Métrica Combinada: 0.6056
#    Modelo salvo: ../results/baseline/RAF-DB/models/efficientvit_m5_best.pth
# Early Stopping: Melhoria detectada (0.6056, Delta=+0.0054)
#
# Época [17/100] - Tempo: 15.41s
#    Train Loss: 0.0448
#    Val Acc: 0.6747 | Val F1: 0.5504
#    Val Precision: 0.5652 | Val Recall: 0.5400
#    Métrica Combinada: 0.6001
# Early Stopping: Sem melhoria (1/15)
#
# Época [18/100] - Tempo: 14.96s
#    Train Loss: 0.0394
#    Val Acc: 0.6750 | Val F1: 0.5591
#    Val Precision: 0.5914 | Val Recall: 0.5433
#    Métrica Combinada: 0.6055
# Early Stopping: Sem melhoria (2/15)
#
# Época [19/100] - Tempo: 15.05s
#    Train Loss: 0.0332
#    Val Acc: 0.6692 | Val F1: 0.5525
#    Val Precision: 0.5682 | Val Recall: 0.5432
#    Métrica Combinada: 0.5992
# Early Stopping: Sem melhoria (3/15)
#
# Época [20/100] - Tempo: 15.12s
#    Train Loss: 0.0387
#    Val Acc: 0.6701 | Val F1: 0.5505
#    Val Precision: 0.5934 | Val Recall: 0.5269
#    Métrica Combinada: 0.5983
# Early Stopping: Sem melhoria (4/15)
#
# Época [21/100] - Tempo: 14.99s
#    Train Loss: 0.0329
#    Val Acc: 0.6662 | Val F1: 0.5405
#    Val Precision: 0.5642 | Val Recall: 0.5253
#    Métrica Combinada: 0.5908
# Early Stopping: Sem melhoria (5/15)
#
# Época [22/100] - Tempo: 14.97s
#    Train Loss: 0.0346
#    Val Acc: 0.6705 | Val F1: 0.5445
#    Val Precision: 0.5712 | Val Recall: 0.5291
#    Métrica Combinada: 0.5949
# Early Stopping: Sem melhoria (6/15)
#
# Época [23/100] - Tempo: 15.09s
#    Train Loss: 0.0328
#    Val Acc: 0.6773 | Val F1: 0.5507
#    Val Precision: 0.5706 | Val Recall: 0.5375
#    Métrica Combinada: 0.6014
# Early Stopping: Sem melhoria (7/15)
#
# Época [24/100] - Tempo: 15.09s
#    Train Loss: 0.0372
#    Val Acc: 0.6714 | Val F1: 0.5457
#    Val Precision: 0.5686 | Val Recall: 0.5313
#    Métrica Combinada: 0.5960
# Early Stopping: Sem melhoria (8/15)
#
# Época [25/100] - Tempo: 15.13s
#    Train Loss: 0.0364
#    Val Acc: 0.6698 | Val F1: 0.5561
#    Val Precision: 0.5768 | Val Recall: 0.5404
#    Métrica Combinada: 0.6016
# Early Stopping: Sem melhoria (9/15)
#
# Época [26/100] - Tempo: 15.06s
#    Train Loss: 0.0310
#    Val Acc: 0.6812 | Val F1: 0.5689
#    Val Precision: 0.5993 | Val Recall: 0.5519
#    Métrica Combinada: 0.6138
#    Modelo salvo: ../results/baseline/RAF-DB/models/efficientvit_m5_best.pth
# Early Stopping: Melhoria detectada (0.6138, Delta=+0.0083)
#
# Época [27/100] - Tempo: 15.15s
#    Train Loss: 0.0391
#    Val Acc: 0.6659 | Val F1: 0.5471
#    Val Precision: 0.5748 | Val Recall: 0.5298
#    Métrica Combinada: 0.5946
# Early Stopping: Sem melhoria (1/15)
#
# Época [28/100] - Tempo: 15.01s
#    Train Loss: 0.0298
#    Val Acc: 0.6842 | Val F1: 0.5656
#    Val Precision: 0.5926 | Val Recall: 0.5471
#    Métrica Combinada: 0.6130
# Early Stopping: Sem melhoria (2/15)
#
# Época [29/100] - Tempo: 15.19s
#    Train Loss: 0.0220
#    Val Acc: 0.6724 | Val F1: 0.5554
#    Val Precision: 0.5618 | Val Recall: 0.5512
#    Métrica Combinada: 0.6022
# Early Stopping: Sem melhoria (3/15)
#
# Época [30/100] - Tempo: 15.06s
#    Train Loss: 0.0200
#    Val Acc: 0.6822 | Val F1: 0.5646
#    Val Precision: 0.6087 | Val Recall: 0.5408
#    Métrica Combinada: 0.6117
# Early Stopping: Sem melhoria (4/15)
#
# Época [31/100] - Tempo: 15.21s
#    Train Loss: 0.0192
#    Val Acc: 0.6757 | Val F1: 0.5582
#    Val Precision: 0.5849 | Val Recall: 0.5419
#    Métrica Combinada: 0.6052
# Early Stopping: Sem melhoria (5/15)
#
# Época [32/100] - Tempo: 15.28s
#    Train Loss: 0.0194
#    Val Acc: 0.6747 | Val F1: 0.5545
#    Val Precision: 0.5710 | Val Recall: 0.5424
#    Métrica Combinada: 0.6026
# Early Stopping: Sem melhoria (6/15)
#
# Época [33/100] - Tempo: 15.13s
#    Train Loss: 0.0211
#    Val Acc: 0.6685 | Val F1: 0.5516
#    Val Precision: 0.5714 | Val Recall: 0.5390
#    Métrica Combinada: 0.5984
# Early Stopping: Sem melhoria (7/15)
#
# Época [34/100] - Tempo: 15.01s
#    Train Loss: 0.0271
#    Val Acc: 0.6757 | Val F1: 0.5446
#    Val Precision: 0.5768 | Val Recall: 0.5258
#    Métrica Combinada: 0.5970
# Early Stopping: Sem melhoria (8/15)
#
# Época [35/100] - Tempo: 14.97s
#    Train Loss: 0.0324
#    Val Acc: 0.6643 | Val F1: 0.5487
#    Val Precision: 0.5551 | Val Recall: 0.5444
#    Métrica Combinada: 0.5949
# Early Stopping: Sem melhoria (9/15)
#
# Época [36/100] - Tempo: 15.33s
#    Train Loss: 0.0298
#    Val Acc: 0.6881 | Val F1: 0.5674
#    Val Precision: 0.5907 | Val Recall: 0.5508
#    Métrica Combinada: 0.6157
#    Modelo salvo: ../results/baseline/RAF-DB/models/efficientvit_m5_best.pth
# Early Stopping: Melhoria detectada (0.6157, Delta=+0.0018)
#
# Época [37/100] - Tempo: 15.11s
#    Train Loss: 0.0251
#    Val Acc: 0.6829 | Val F1: 0.5526
#    Val Precision: 0.6060 | Val Recall: 0.5270
#    Métrica Combinada: 0.6047
# Early Stopping: Sem melhoria (1/15)
#
# Época [38/100] - Tempo: 15.29s
#    Train Loss: 0.0231
#    Val Acc: 0.6868 | Val F1: 0.5714
#    Val Precision: 0.5955 | Val Recall: 0.5565
#    Métrica Combinada: 0.6176
#    Modelo salvo: ../results/baseline/RAF-DB/models/efficientvit_m5_best.pth
# Early Stopping: Melhoria detectada (0.6176, Delta=+0.0019)
#
# Época [39/100] - Tempo: 15.12s
#    Train Loss: 0.0220
#    Val Acc: 0.6842 | Val F1: 0.5602
#    Val Precision: 0.5820 | Val Recall: 0.5469
#    Métrica Combinada: 0.6098
# Early Stopping: Sem melhoria (1/15)
#
# Época [40/100] - Tempo: 15.35s
#    Train Loss: 0.0209
#    Val Acc: 0.6825 | Val F1: 0.5556
#    Val Precision: 0.5724 | Val Recall: 0.5433
#    Métrica Combinada: 0.6064
# Early Stopping: Sem melhoria (2/15)
#
# Época [41/100] - Tempo: 15.08s
#    Train Loss: 0.0219
#    Val Acc: 0.6887 | Val F1: 0.5658
#    Val Precision: 0.5950 | Val Recall: 0.5465
#    Métrica Combinada: 0.6150
# Early Stopping: Sem melhoria (3/15)
#
# Época [42/100] - Tempo: 15.21s
#    Train Loss: 0.0179
#    Val Acc: 0.6822 | Val F1: 0.5601
#    Val Precision: 0.5828 | Val Recall: 0.5452
#    Métrica Combinada: 0.6090
# Early Stopping: Sem melhoria (4/15)
#
# Época [43/100] - Tempo: 15.18s
#    Train Loss: 0.0129
#    Val Acc: 0.6832 | Val F1: 0.5698
#    Val Precision: 0.5992 | Val Recall: 0.5524
#    Métrica Combinada: 0.6152
# Early Stopping: Sem melhoria (5/15)
#
# Época [44/100] - Tempo: 15.10s
#    Train Loss: 0.0149
#    Val Acc: 0.6842 | Val F1: 0.5597
#    Val Precision: 0.5842 | Val Recall: 0.5445
#    Métrica Combinada: 0.6095
# Early Stopping: Sem melhoria (6/15)
#
# Época [45/100] - Tempo: 15.30s
#    Train Loss: 0.0160
#    Val Acc: 0.6946 | Val F1: 0.5733
#    Val Precision: 0.6013 | Val Recall: 0.5549
#    Métrica Combinada: 0.6218
#    Modelo salvo: ../results/baseline/RAF-DB/models/efficientvit_m5_best.pth
# Early Stopping: Melhoria detectada (0.6218, Delta=+0.0042)
#
# Época [46/100] - Tempo: 15.19s
#    Train Loss: 0.0115
#    Val Acc: 0.6848 | Val F1: 0.5639
#    Val Precision: 0.5892 | Val Recall: 0.5474
#    Métrica Combinada: 0.6123
# Early Stopping: Sem melhoria (1/15)
#
# Época [47/100] - Tempo: 15.28s
#    Train Loss: 0.0168
#    Val Acc: 0.6930 | Val F1: 0.5741
#    Val Precision: 0.5956 | Val Recall: 0.5611
#    Métrica Combinada: 0.6216
# Early Stopping: Sem melhoria (2/15)
#
# Época [48/100] - Tempo: 15.15s
#    Train Loss: 0.0178
#    Val Acc: 0.6890 | Val F1: 0.5681
#    Val Precision: 0.5826 | Val Recall: 0.5573
#    Métrica Combinada: 0.6165
# Early Stopping: Sem melhoria (3/15)
#
# Época [49/100] - Tempo: 15.19s
#    Train Loss: 0.0220
#    Val Acc: 0.6835 | Val F1: 0.5593
#    Val Precision: 0.5858 | Val Recall: 0.5433
#    Métrica Combinada: 0.6090
# Early Stopping: Sem melhoria (4/15)
#
# Época [50/100] - Tempo: 15.07s
#    Train Loss: 0.0212
#    Val Acc: 0.6848 | Val F1: 0.5581
#    Val Precision: 0.5777 | Val Recall: 0.5449
#    Métrica Combinada: 0.6088
# Early Stopping: Sem melhoria (5/15)
#
# Época [51/100] - Tempo: 15.28s
#    Train Loss: 0.0189
#    Val Acc: 0.6894 | Val F1: 0.5688
#    Val Precision: 0.5891 | Val Recall: 0.5543
#    Métrica Combinada: 0.6170
# Early Stopping: Sem melhoria (6/15)
#
# Época [52/100] - Tempo: 15.24s
#    Train Loss: 0.0139
#    Val Acc: 0.6855 | Val F1: 0.5643
#    Val Precision: 0.5957 | Val Recall: 0.5439
#    Métrica Combinada: 0.6128
# Early Stopping: Sem melhoria (7/15)
#
# Época [53/100] - Tempo: 15.30s
#    Train Loss: 0.0127
#    Val Acc: 0.6819 | Val F1: 0.5537
#    Val Precision: 0.5757 | Val Recall: 0.5415
#    Métrica Combinada: 0.6049
# Early Stopping: Sem melhoria (8/15)
#
# Época [54/100] - Tempo: 15.45s
#    Train Loss: 0.0180
#    Val Acc: 0.6946 | Val F1: 0.5784
#    Val Precision: 0.6037 | Val Recall: 0.5622
#    Métrica Combinada: 0.6249
#    Modelo salvo: ../results/baseline/RAF-DB/models/efficientvit_m5_best.pth
# Early Stopping: Melhoria detectada (0.6249, Delta=+0.0031)
#
# Época [55/100] - Tempo: 15.04s
#    Train Loss: 0.0165
#    Val Acc: 0.6949 | Val F1: 0.5740
#    Val Precision: 0.6018 | Val Recall: 0.5578
#    Métrica Combinada: 0.6224
# Early Stopping: Sem melhoria (1/15)
#
# Época [56/100] - Tempo: 15.26s
#    Train Loss: 0.0142
#    Val Acc: 0.6982 | Val F1: 0.5828
#    Val Precision: 0.6105 | Val Recall: 0.5654
#    Métrica Combinada: 0.6289
#    Modelo salvo: ../results/baseline/RAF-DB/models/efficientvit_m5_best.pth
# Early Stopping: Melhoria detectada (0.6289, Delta=+0.0041)
#
# Época [57/100] - Tempo: 15.12s
#    Train Loss: 0.0163
#    Val Acc: 0.6949 | Val F1: 0.5733
#    Val Precision: 0.6128 | Val Recall: 0.5559
#    Métrica Combinada: 0.6219
# Early Stopping: Sem melhoria (1/15)
#
# Época [58/100] - Tempo: 15.12s
#    Train Loss: 0.0175
#    Val Acc: 0.6978 | Val F1: 0.5819
#    Val Precision: 0.6032 | Val Recall: 0.5680
#    Métrica Combinada: 0.6283
# Early Stopping: Sem melhoria (2/15)
#
# Época [59/100] - Tempo: 15.19s
#    Train Loss: 0.0159
#    Val Acc: 0.6982 | Val F1: 0.5832
#    Val Precision: 0.6044 | Val Recall: 0.5673
#    Métrica Combinada: 0.6292
#    Modelo salvo: ../results/baseline/RAF-DB/models/efficientvit_m5_best.pth
# Early Stopping: Sem melhoria (3/15)
#
# Época [60/100] - Tempo: 14.95s
#    Train Loss: 0.0154
#    Val Acc: 0.6962 | Val F1: 0.5754
#    Val Precision: 0.6072 | Val Recall: 0.5580
#    Métrica Combinada: 0.6237
# Early Stopping: Sem melhoria (4/15)
#
# Época [61/100] - Tempo: 15.09s
#    Train Loss: 0.0128
#    Val Acc: 0.6936 | Val F1: 0.5817
#    Val Precision: 0.6014 | Val Recall: 0.5691
#    Métrica Combinada: 0.6265
# Early Stopping: Sem melhoria (5/15)
#
# Época [62/100] - Tempo: 15.26s
#    Train Loss: 0.0090
#    Val Acc: 0.6969 | Val F1: 0.5832
#    Val Precision: 0.6211 | Val Recall: 0.5599
#    Métrica Combinada: 0.6287
# Early Stopping: Sem melhoria (6/15)
#
# Época [63/100] - Tempo: 14.97s
#    Train Loss: 0.0104
#    Val Acc: 0.6975 | Val F1: 0.5962
#    Val Precision: 0.6424 | Val Recall: 0.5697
#    Métrica Combinada: 0.6367
#    Modelo salvo: ../results/baseline/RAF-DB/models/efficientvit_m5_best.pth
# Early Stopping: Melhoria detectada (0.6367, Delta=+0.0078)
#
# Época [64/100] - Tempo: 15.19s
#    Train Loss: 0.0082
#    Val Acc: 0.6943 | Val F1: 0.5821
#    Val Precision: 0.6138 | Val Recall: 0.5612
#    Métrica Combinada: 0.6270
# Early Stopping: Sem melhoria (1/15)
#
# Época [65/100] - Tempo: 15.14s
#    Train Loss: 0.0150
#    Val Acc: 0.6871 | Val F1: 0.5631
#    Val Precision: 0.6033 | Val Recall: 0.5428
#    Métrica Combinada: 0.6127
# Early Stopping: Sem melhoria (2/15)
#
# Época [66/100] - Tempo: 15.09s
#    Train Loss: 0.0185
#    Val Acc: 0.7037 | Val F1: 0.5870
#    Val Precision: 0.6197 | Val Recall: 0.5679
#    Métrica Combinada: 0.6337
# Early Stopping: Sem melhoria (3/15)
#
# Época [67/100] - Tempo: 15.03s
#    Train Loss: 0.0190
#    Val Acc: 0.6975 | Val F1: 0.5908
#    Val Precision: 0.6341 | Val Recall: 0.5703
#    Métrica Combinada: 0.6335
# Early Stopping: Sem melhoria (4/15)
#
# Época [68/100] - Tempo: 15.10s
#    Train Loss: 0.0203
#    Val Acc: 0.6900 | Val F1: 0.5743
#    Val Precision: 0.5953 | Val Recall: 0.5593
#    Métrica Combinada: 0.6206
# Early Stopping: Sem melhoria (5/15)
#
# Época [69/100] - Tempo: 15.15s
#    Train Loss: 0.0147
#    Val Acc: 0.6992 | Val F1: 0.5827
#    Val Precision: 0.6236 | Val Recall: 0.5625
#    Métrica Combinada: 0.6293
# Early Stopping: Sem melhoria (6/15)
#
# Época [70/100] - Tempo: 15.09s
#    Train Loss: 0.0100
#    Val Acc: 0.7005 | Val F1: 0.5858
#    Val Precision: 0.6223 | Val Recall: 0.5636
#    Métrica Combinada: 0.6317
# Early Stopping: Sem melhoria (7/15)
#
# Época [71/100] - Tempo: 15.44s
#    Train Loss: 0.0139
#    Val Acc: 0.6995 | Val F1: 0.5825
#    Val Precision: 0.6152 | Val Recall: 0.5662
#    Métrica Combinada: 0.6293
# Early Stopping: Sem melhoria (8/15)
#
# Época [72/100] - Tempo: 15.06s
#    Train Loss: 0.0088
#    Val Acc: 0.7014 | Val F1: 0.5806
#    Val Precision: 0.6338 | Val Recall: 0.5557
#    Métrica Combinada: 0.6290
# Early Stopping: Sem melhoria (9/15)
#
# Época [73/100] - Tempo: 15.09s
#    Train Loss: 0.0086
#    Val Acc: 0.7034 | Val F1: 0.5751
#    Val Precision: 0.6159 | Val Recall: 0.5552
#    Métrica Combinada: 0.6264
# Early Stopping: Sem melhoria (10/15)
#
# Época [74/100] - Tempo: 15.11s
#    Train Loss: 0.0110
#    Val Acc: 0.7050 | Val F1: 0.5799
#    Val Precision: 0.6316 | Val Recall: 0.5574
#    Métrica Combinada: 0.6300
# Early Stopping: Sem melhoria (11/15)
#
# Época [75/100] - Tempo: 15.17s
#    Train Loss: 0.0159
#    Val Acc: 0.6913 | Val F1: 0.5695
#    Val Precision: 0.6105 | Val Recall: 0.5458
#    Métrica Combinada: 0.6182
# Early Stopping: Sem melhoria (12/15)
#
# Época [76/100] - Tempo: 14.98s
#    Train Loss: 0.0144
#    Val Acc: 0.6975 | Val F1: 0.5803
#    Val Precision: 0.6036 | Val Recall: 0.5649
#    Métrica Combinada: 0.6272
# Early Stopping: Sem melhoria (13/15)
#
# Época [77/100] - Tempo: 15.11s
#    Train Loss: 0.0109
#    Val Acc: 0.6920 | Val F1: 0.5821
#    Val Precision: 0.6257 | Val Recall: 0.5588
#    Métrica Combinada: 0.6260
# Early Stopping: Sem melhoria (14/15)
#
# Época [78/100] - Tempo: 15.11s
#    Train Loss: 0.0083
#    Val Acc: 0.6965 | Val F1: 0.5855
#    Val Precision: 0.6277 | Val Recall: 0.5605
#    Métrica Combinada: 0.6299
# Early Stopping: Sem melhoria (15/15)
# Early Stopping: Treinamento interrompido após 15 épocas sem melhoria
#
# Early stopping ativado na época 78
#
# ======================================================================
# MONITORING REPORT: EFFICIENTVIT_M5
# ======================================================================
# Total training time: 0:19:47
# Initial RAM: 1589.21 MB
# Final RAM: 1837.27 MB
# Peak RAM: 1837.59 MB
# Memory increase: 248.06 MB
# Peak GPU Memory: 3121.62 MB
# Final GPU Memory: 211.16 MB
# ======================================================================
#
# Avaliando modelo no conjunto de teste...
# Testando: 100%|██████████| 48/48 [00:01<00:00, 38.67it/s]
# ======================================================================
# RESULTADOS DA AVALIAÇÃO - CONJUNTO DE TESTE
# ======================================================================
# Acurácia: 0.6969
#
# Métricas Macro:
#    Precisão: 0.6429
#    Recall: 0.5712
#    F1-Score: 0.5977
#
# F1-Score Weighted: 0.6897
# ======================================================================
#
#
# Métricas por Classe:
# Classe          Precisão     Recall       F1-Score     Suporte
# ----------------------------------------------------------------------
# Raiva           0.6489       0.5247       0.5802       162
# Nojo            0.3884       0.2938       0.3345       160
# Medo            0.7561       0.4189       0.5391       74
# Felicidade      0.7930       0.8793       0.8339       1185
# Neutro          0.6434       0.6500       0.6467       680
# Tristeza        0.6293       0.5753       0.6011       478
# Surpresa        0.6409       0.6565       0.6486       329
# ----------------------------------------------------------------------
# Métricas salvas: ../results/baseline/RAF-DB/metrics/efficientvit_m5_metrics_20251031_175124.json
# Matrizes de confusão salvas: ../results/baseline/RAF-DB/plots/efficientvit_m5_confusion_20251031_175124.png
# Histórico de treinamento salvo: ../results/baseline/RAF-DB/plots/efficientvit_m5_history_20251031_175124.png
#
# Todos os resultados salvos para efficientvit_m5
#
# ================================================================================
# COMPARAÇÃO FINAL - TODOS OS MODELOS
# ================================================================================
#
#      model_name  test_accuracy  test_f1_macro  test_f1_weighted  epochs_completed
#        resnet50       0.783246       0.688551          0.780059                46
# efficientnet_b0       0.757497       0.666096          0.755511                43
# efficientvit_m5       0.696871       0.597743          0.689729                78
#
# Comparação salva: ../results/baseline/RAF-DB/metrics/model_comparison.csv
#
# Melhor modelo (por acurácia): resnet50 - 0.7832
#
# ================================================================================
# TREINAMENTO BASELINE CONCLUÍDO
# ================================================================================
