# %%
"""
=============================================================================
TREINAMENTO EXPW COM AUGMENTATION ONLINE AGRESSIVO (80%)
=============================================================================
Pipeline de treinamento com augmentation online forte:
1. Carrega dataset augmented_expw (já balanceado offline)
2. Aplica augmentation ONLINE agressivo (p=0.8) - 80% das imagens
3. Treina múltiplos modelos: ResNet50, EfficientNet-B0, ViT
4. Early stopping para evitar overfitting
5. Métricas completas para comparação

ESTRATÉGIA:
- Dataset base: augmented_expw (balanceado offline)
- Augmentation online: MUITO AGRESSIVO (p=0.8) - NÃO salva em disco
- Modelos: 3 arquiteturas diferentes
- Métricas: Completas (Acc, F1, Precision, Recall, por classe)
- Early Stopping: Patience=15

DIFERENCIAL:
- 80% das imagens sofrem transformação A CADA ÉPOCA
- Máxima variabilidade sem explodir armazenamento
- Transformações mais fortes que offline

=============================================================================
"""

import os
import cv2
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
import time
import psutil
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.models as models
import albumentations as A
from albumentations.pytorch import ToTensorV2
from sklearn.metrics import (
    accuracy_score, f1_score, precision_score, recall_score,
    classification_report, confusion_matrix, precision_recall_fscore_support
)
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import gc

warnings.filterwarnings('ignore')

# %%
# =============================================================================
# CONFIGURAÇÕES
# =============================================================================

# CONFIGURAÇÕES
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
DATASET_PATH = r"../data/augmented/EXPW"
RESULTS_PATH = r"../results/augmented_online/EXPW"
MODELS_PATH = os.path.join(RESULTS_PATH, "models")
METRICS_PATH = os.path.join(RESULTS_PATH, "metrics")
PLOTS_PATH = os.path.join(RESULTS_PATH, "plots")

os.makedirs(MODELS_PATH, exist_ok=True)
os.makedirs(METRICS_PATH, exist_ok=True)
os.makedirs(PLOTS_PATH, exist_ok=True)

EPOCHS = 100
LR = 1e-4
BATCH_SIZE = 32
NUM_WORKERS = 4
EARLY_STOP_PATIENCE = 15
EARLY_STOP_MIN_DELTA = 0.001
F1_WEIGHT = 0.6
ACC_WEIGHT = 0.4

EMOTION_LABELS = {
    'Raiva': 0, 
    'Nojo': 1, 
    'Medo': 2, 
    'Felicidade': 3,
    'Neutro': 4, 
    'Tristeza': 5, 
    'Surpresa': 6
}

if DEVICE == "cuda":
    torch.cuda.empty_cache()
    gc.collect()
    os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'

print("="*80)
print("TREINAMENTO EXPW - DADOS BALANCEADOS")
print("="*80)
print(f"Dispositivo: {DEVICE}")
if DEVICE == "cuda":
    print(f"GPU: {torch.cuda.get_device_name(0)}")
print(f"Dataset: {DATASET_PATH}")
print("="*80)
# Out:
# ================================================================================
# TREINAMENTO EXPW - DADOS BALANCEADOS
# ================================================================================
# Dispositivo: cuda
# GPU: NVIDIA GeForce RTX 2080
# Dataset: ../data/augmented/EXPW
# ================================================================================

# %%
# CLASSE DE MONITORAMENTO
class ResourceMonitor:
    def __init__(self, model_name):
        self.model_name = model_name
        self.start_time = None
        self.end_time = None
        self.peak_memory_mb = 0
        self.initial_memory_mb = 0
        self.training_time = 0
        self.process = psutil.Process()
        self.peak_gpu_memory_mb = 0
        self.initial_gpu_memory_mb = 0
        
    def start_monitoring(self):
        self.start_time = time.time()
        self.initial_memory_mb = self._get_memory_usage()
        self.peak_memory_mb = self.initial_memory_mb
        
        if torch.cuda.is_available():
            self.initial_gpu_memory_mb = torch.cuda.memory_allocated() / 1024**2
            self.peak_gpu_memory_mb = self.initial_gpu_memory_mb
        
        print(f"\n🔍 Iniciando monitoramento: {self.model_name}")
        print(f"  • Initial RAM: {self.initial_memory_mb:.2f} MB")
        if torch.cuda.is_available():
            print(f"  • Initial GPU: {self.initial_gpu_memory_mb:.2f} MB")
        
    def _get_memory_usage(self):
        return self.process.memory_info().rss / 1024 / 1024
        
    def update_peak_memory(self):
        current_memory = self._get_memory_usage()
        if current_memory > self.peak_memory_mb:
            self.peak_memory_mb = current_memory
        
        if torch.cuda.is_available():
            current_gpu = torch.cuda.max_memory_allocated() / 1024**2
            if current_gpu > self.peak_gpu_memory_mb:
                self.peak_gpu_memory_mb = current_gpu
            
    def end_monitoring(self):
        self.end_time = time.time()
        self.training_time = self.end_time - self.start_time
        final_memory_mb = self._get_memory_usage()
        memory_increase = final_memory_mb - self.initial_memory_mb
        
        print("\n" + "="*70)
        print(f"MONITORING REPORT: {self.model_name.upper()}")
        print("="*70)
        print(f"Total training time: {timedelta(seconds=int(self.training_time))}")
        print(f"Initial RAM: {self.initial_memory_mb:.2f} MB")
        print(f"Final RAM: {final_memory_mb:.2f} MB")
        print(f"Peak RAM: {self.peak_memory_mb:.2f} MB")
        print(f"Memory increase: {memory_increase:.2f} MB")
        
        if torch.cuda.is_available():
            final_gpu = torch.cuda.memory_allocated() / 1024**2
            print(f"Peak GPU Memory: {self.peak_gpu_memory_mb:.2f} MB")
            print(f"Final GPU Memory: {final_gpu:.2f} MB")
        
        print("="*70)
        
        return {
            'training_time_seconds': self.training_time,
            'initial_memory_mb': self.initial_memory_mb,
            'final_memory_mb': final_memory_mb,
            'peak_memory_mb': self.peak_memory_mb,
            'memory_increase_mb': memory_increase,
            'peak_gpu_memory_mb': self.peak_gpu_memory_mb if torch.cuda.is_available() else 0
        }

# %%
# EARLY STOPPING
class EarlyStopping:
    def __init__(self, patience=15, min_delta=0.001, mode='max', verbose=True):
        self.patience = patience
        self.min_delta = min_delta
        self.mode = mode
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_score_min = np.inf if mode == 'min' else -np.inf
        
    def __call__(self, val_score):
        if self.mode == 'max':
            score = val_score
        else:
            score = -val_score
            
        if self.best_score is None:
            self.best_score = score
            self.val_score_min = val_score
            if self.verbose:
                print(f'Early Stopping: Baseline: {val_score:.4f}')
        elif score < self.best_score + self.min_delta:
            self.counter += 1
            if self.verbose:
                print(f'Early Stopping: Sem melhoria ({self.counter}/{self.patience})')
            if self.counter >= self.patience:
                self.early_stop = True
                if self.verbose:
                    print(f'Early Stopping: ATIVADO após {self.patience} épocas')
        else:
            if self.verbose:
                improvement = val_score - self.val_score_min
                print(f'Early Stopping: Melhoria! ({val_score:.4f}, Δ={improvement:+.4f})')
            self.best_score = score
            self.val_score_min = val_score
            self.counter = 0
            
        return self.early_stop

# %%
# AUGMENTATION
def create_train_transform():
    return A.Compose([
        A.OneOf([
            A.HorizontalFlip(p=1.0),
            A.Rotate(limit=20, p=1.0),
            A.ShiftScaleRotate(shift_limit=0.15, scale_limit=0.15, rotate_limit=20, p=1.0),
            A.RandomBrightnessContrast(brightness_limit=0.3, contrast_limit=0.3, p=1.0),
            A.GaussNoise(var_limit=(15.0, 50.0), p=1.0),
            A.GaussianBlur(blur_limit=(3, 7), p=1.0),
        ], p=0.8),
        A.Resize(height=224, width=224),
        A.Normalize(mean=[0.5], std=[0.5]),
        ToTensorV2(),
    ])

def create_val_transform():
    return A.Compose([
        A.Resize(height=224, width=224),
        A.Normalize(mean=[0.5], std=[0.5]),
        ToTensorV2(),
    ])

# %%
# DATASET
class EmotionDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.image_paths = []
        self.labels = []

        for class_name, class_idx in EMOTION_LABELS.items():
            class_path = os.path.join(self.root_dir, class_name)
            if os.path.isdir(class_path):
                for img_name in os.listdir(class_path):
                    if img_name.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp')):
                        self.image_paths.append(os.path.join(class_path, img_name))
                        self.labels.append(class_idx)

        if len(self.image_paths) == 0:
            raise ValueError(f"Nenhuma imagem em {root_dir}")

    def __len__(self):
        return len(self.image_paths)
    
    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        label = self.labels[idx]
        image = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        
        if image is None:
            raise ValueError(f"Erro ao carregar: {img_path}")
        
        if self.transform:
            augmented = self.transform(image=image)
            image = augmented['image']

        return image, torch.tensor(label, dtype=torch.long)

# %%
# MODELOS
def create_model(model_name):
    num_classes = len(EMOTION_LABELS)
    
    try:
        if model_name == 'resnet50':
            model = models.resnet50(weights=models.ResNet50_Weights.IMAGENET1K_V2)
            model.conv1 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)
            model.fc = nn.Linear(model.fc.in_features, num_classes)
            
        elif model_name == 'efficientnet_b0':
            model = models.efficientnet_b0(weights=models.EfficientNet_B0_Weights.IMAGENET1K_V1)
            model.features[0][0] = nn.Conv2d(1, 32, kernel_size=3, stride=2, padding=1, bias=False)
            model.classifier[1] = nn.Linear(model.classifier[1].in_features, num_classes)
            
        elif model_name == 'vit_b_16':
            model = models.vit_b_16(weights=models.ViT_B_16_Weights.IMAGENET1K_V1)
            model.conv_proj = nn.Conv2d(1, 768, kernel_size=16, stride=16)
            model.heads.head = nn.Linear(model.heads.head.in_features, num_classes)
            
        else:
            print(f"❌ Modelo '{model_name}' não suportado")
            return None
        
        print(f"✓ Modelo '{model_name}' criado")
        return model
        
    except Exception as e:
        print(f"❌ Erro ao criar modelo '{model_name}': {e}")
        return None

# %%
def create_comprehensive_visualizations(history, conf_matrix, metrics, class_report, 
                                       experiment_id, y_true, y_pred, model_name, 
                                       train_distribution):
    """
    Visualizações completas com comparação train vs test.
    
    Args:
        train_distribution: dict com contagem de classes do treino
                           formato: {0: count, 1: count, ...}
    """
    fig = plt.figure(figsize=(24, 18))
    emotion_names = list(EMOTION_LABELS.keys())
    
    # 1. ACCURACY
    ax1 = plt.subplot(3, 4, 1)
    epochs = range(1, len(history['val_accuracy']) + 1)
    plt.plot(epochs, [acc * 100 for acc in history['val_accuracy']], 
             'b-', linewidth=2, label='Val Accuracy', marker='o', markersize=3)
    plt.title(f'{model_name.upper()}: Accuracy Evolution', fontsize=14, fontweight='bold')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.legend(fontsize=10)
    plt.grid(True, alpha=0.3)
    
    # 2. LOSS
    ax2 = plt.subplot(3, 4, 2)
    plt.plot(epochs, history['train_loss'], 
             'r-', linewidth=2, label='Train Loss', marker='o', markersize=3)
    plt.title(f'{model_name.upper()}: Loss Evolution', fontsize=14, fontweight='bold')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(fontsize=10)
    plt.grid(True, alpha=0.3)
    
    # 3. MATRIZ RAW
    ax3 = plt.subplot(3, 4, 3)
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
                xticklabels=emotion_names, yticklabels=emotion_names, ax=ax3,
                cbar_kws={'label': 'Amostras'})
    plt.title('Matriz de Confusão (Test)', fontsize=12, fontweight='bold')
    plt.ylabel('Classe Verdadeira')
    plt.xlabel('Classe Predita')
    plt.xticks(rotation=45)
    plt.yticks(rotation=0)
    
    # 4. MATRIZ NORMALIZADA
    ax4 = plt.subplot(3, 4, 4)
    conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]
    conf_matrix_norm = np.nan_to_num(conf_matrix_norm)
    sns.heatmap(conf_matrix_norm, annot=True, fmt='.3f', cmap='Greens',
                xticklabels=emotion_names, yticklabels=emotion_names, ax=ax4,
                cbar_kws={'label': 'Proporção'})
    plt.title('Matriz Normalizada (Recall)', fontsize=12, fontweight='bold')
    plt.ylabel('Classe Verdadeira')
    plt.xlabel('Classe Predita')
    plt.xticks(rotation=45)
    plt.yticks(rotation=0)
    
    # 5. DISTRIBUIÇÃO TRAIN VS TEST ← MODIFICADO
    ax5 = plt.subplot(3, 4, 5)
    
    # Dados do TESTE
    unique_test, counts_test = np.unique(y_true, return_counts=True)
    test_dist = dict(zip(unique_test, counts_test))
    
    # Organizar dados para plotagem
    train_counts = [train_distribution.get(i, 0) for i in range(len(emotion_names))]
    test_counts = [test_dist.get(i, 0) for i in range(len(emotion_names))]
    
    x = np.arange(len(emotion_names))
    width = 0.35
    
    bars1 = plt.bar(x - width/2, train_counts, width, label='Train (Balanceado)', 
                   alpha=0.8, color='steelblue', edgecolor='black')
    bars2 = plt.bar(x + width/2, test_counts, width, label='Test (Original)', 
                   alpha=0.8, color='coral', edgecolor='black')
    
    plt.title('Distribuição: Train vs Test', fontsize=12, fontweight='bold')
    plt.ylabel('Amostras')
    plt.xlabel('Emoção')
    plt.xticks(x, emotion_names, rotation=45)
    plt.legend()
    plt.grid(True, alpha=0.3, axis='y')
    
    # Adicionar valores nas barras
    for bars in [bars1, bars2]:
        for bar in bars:
            height = bar.get_height()
            plt.text(bar.get_x() + bar.get_width()/2, height + max(train_counts + test_counts)*0.01,
                    f'{int(height)}', ha='center', va='bottom', fontsize=8)
    
    # 6. F1-SCORE (Test)
    ax6 = plt.subplot(3, 4, 6)
    f1_scores = [class_report[emotion]['f1-score'] for emotion in emotion_names]
    support_counts = [class_report[emotion]['support'] for emotion in emotion_names]
    bars = plt.bar(emotion_names, f1_scores, color='steelblue', alpha=0.8, edgecolor='black')
    plt.title('F1-Score por Emoção (Test)', fontsize=12, fontweight='bold')
    plt.ylabel('F1-Score')
    plt.xticks(rotation=45)
    plt.ylim(0, 1)
    for bar, score, support in zip(bars, f1_scores, support_counts):
        plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01,
                f'{score:.3f}\n(n={support})', ha='center', va='bottom', fontsize=9)
    
    # 7. PRECISION, RECALL, F1
    ax7 = plt.subplot(3, 4, 7)
    precision_scores = [class_report[emotion]['precision'] for emotion in emotion_names]
    recall_scores = [class_report[emotion]['recall'] for emotion in emotion_names]
    x = np.arange(len(emotion_names))
    width = 0.25
    bars1 = plt.bar(x - width, precision_scores, width, label='Precision', alpha=0.8, color='lightcoral')
    bars2 = plt.bar(x, recall_scores, width, label='Recall', alpha=0.8, color='lightblue')
    bars3 = plt.bar(x + width, f1_scores, width, label='F1-Score', alpha=0.8, color='lightgreen')
    plt.title('Métricas por Classe (Test)', fontsize=12, fontweight='bold')
    plt.ylabel('Score')
    plt.xlabel('Emoção')
    plt.xticks(x, emotion_names, rotation=45)
    plt.legend()
    plt.ylim(0, 1)
    
    # 8. F1 MACRO VS WEIGHTED
    ax8 = plt.subplot(3, 4, 8)
    precision_macro, recall_macro, f1_macro, _ = precision_recall_fscore_support(
        y_true, y_pred, average='macro', zero_division=0)
    precision_weighted, recall_weighted, f1_weighted, _ = precision_recall_fscore_support(
        y_true, y_pred, average='weighted', zero_division=0)
    metrics_comparison = {
        'Precision': [precision_macro, precision_weighted],
        'Recall': [recall_macro, recall_weighted],
        'F1-Score': [f1_macro, f1_weighted]
    }
    x = np.arange(len(metrics_comparison))
    width = 0.35
    macro_values = [metrics_comparison[metric][0] for metric in metrics_comparison]
    weighted_values = [metrics_comparison[metric][1] for metric in metrics_comparison]
    bars1 = plt.bar(x - width/2, macro_values, width, label='Macro', alpha=0.8, color='lightcoral')
    bars2 = plt.bar(x + width/2, weighted_values, width, label='Weighted', alpha=0.8, color='lightblue')
    plt.title('Macro vs Weighted (Test)', fontsize=12, fontweight='bold')
    plt.ylabel('Score')
    plt.xlabel('Métrica')
    plt.xticks(x, metrics_comparison.keys())
    plt.legend()
    plt.ylim(0, 1)
    for bars in [bars1, bars2]:
        for bar in bars:
            height = bar.get_height()
            plt.text(bar.get_x() + bar.get_width()/2, height + 0.01,
                    f'{height:.3f}', ha='center', va='bottom', fontsize=10)
    
    # 9. HEATMAP ERROS
    ax9 = plt.subplot(3, 4, 9)
    error_matrix = conf_matrix.copy()
    np.fill_diagonal(error_matrix, 0)
    error_matrix_norm = error_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]
    error_matrix_norm = np.nan_to_num(error_matrix_norm)
    sns.heatmap(error_matrix_norm, annot=True, fmt='.3f', cmap='Reds',
                xticklabels=emotion_names, yticklabels=emotion_names, ax=ax9,
                cbar_kws={'label': 'Proporção de Erros'})
    plt.title('Heatmap de Erros (Test)', fontsize=12, fontweight='bold')
    plt.ylabel('Classe Verdadeira')
    plt.xlabel('Classe Predita')
    plt.xticks(rotation=45)
    plt.yticks(rotation=0)
    
    # 10. F1 POR ÉPOCA
    ax10 = plt.subplot(3, 4, 10)
    plt.plot(epochs, history['val_f1_macro'], 'g-', linewidth=2, 
             label='Val F1-Macro', marker='o', markersize=3)
    plt.title('F1-Score Evolution', fontsize=12, fontweight='bold')
    plt.xlabel('Epoch')
    plt.ylabel('F1-Score')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # 11. RECURSOS COMPUTACIONAIS
    ax11 = plt.subplot(3, 4, 11)
    resource_data = {
        'Tempo (min)': metrics['training_time_seconds'] / 60,
        'Memória (GB)': metrics['peak_memory_mb'] / 1024,
        'Parâmetros (M)': metrics['total_parameters'] / 1_000_000,
        'Eficiência': metrics['test_accuracy'] / (metrics['total_parameters'] / 1_000_000)
    }
    colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']
    bars = plt.bar(range(len(resource_data)), list(resource_data.values()), 
                  color=colors, alpha=0.7, edgecolor='black')
    plt.title(f'Recursos Computacionais\n{model_name.upper()}', fontsize=12, fontweight='bold')
    plt.xticks(range(len(resource_data)), resource_data.keys(), rotation=45)
    plt.ylabel('Valor')
    for bar, (key, value) in zip(bars, resource_data.items()):
        plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + bar.get_height()*0.02,
                f'{value:.2f}', ha='center', va='bottom', fontweight='bold')
    
    # 12. RESUMO
    ax12 = plt.subplot(3, 4, 12)
    ax12.axis('off')
    
    # Calcular diferença de balanceamento
    train_max = max(train_counts)
    train_min = min(train_counts)
    test_max = max(test_counts)
    test_min = min(test_counts)
    train_ratio = train_max / train_min if train_min > 0 else 0
    test_ratio = test_max / test_min if test_min > 0 else 0
    
    summary_text = f"""
{model_name.upper()}
RESUMO

PERFORMANCE (Test):
- Accuracy: {metrics['test_accuracy']:.4f}
- F1-Macro: {f1_macro:.4f}
- F1-Weighted: {f1_weighted:.4f}

DISTRIBUIÇÃO:
- Train Ratio: {train_ratio:.1f}:1
- Test Ratio: {test_ratio:.1f}:1

RECURSOS:
- Parâmetros: {metrics['total_parameters']/1_000_000:.1f}M
- Tempo: {metrics['training_time_seconds']/60:.1f} min
- Memória: {metrics['peak_memory_mb']/1024:.2f} GB

MELHOR/PIOR (Test):
- Melhor: {emotion_names[np.argmax(f1_scores)]} ({max(f1_scores):.3f})
- Pior: {emotion_names[np.argmin(f1_scores)]} ({min(f1_scores):.3f})
    """
    ax12.text(0.05, 0.95, summary_text, fontsize=11, verticalalignment='top',
             transform=ax12.transAxes,
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
    
    plt.tight_layout()
    plt.savefig(os.path.join(PLOTS_PATH, f'{model_name}_analysis_{experiment_id}.png'), 
                dpi=300, bbox_inches='tight')
    plt.show()

# %%
# TREINAMENTO
def train_epoch(model, train_loader, criterion, optimizer, device, scaler):
    model.train()
    running_loss = 0.0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        with torch.cuda.amp.autocast(enabled=(device == "cuda")):
            outputs = model(images)
            loss = criterion(outputs, labels)
        optimizer.zero_grad()
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        running_loss += loss.item()
    return running_loss / len(train_loader)

def validate(model, val_loader, device):
    model.eval()
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            with torch.cuda.amp.autocast(enabled=(device == "cuda")):
                outputs = model(images)
            preds = torch.argmax(outputs, dim=1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    return np.array(all_preds), np.array(all_labels)

def train_model(model_name, train_loader, val_loader, device, epochs, early_stopping, monitor):
    print(f"\n{'='*80}")
    print(f"TREINANDO: {model_name.upper()}")
    print(f"{'='*80}")
    
    monitor.start_monitoring()
    
    model = create_model(model_name)
    if model is None:
        return None
    
    model.to(device)
    
    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"\n📊 Parâmetros: {total_params:,} (Treináveis: {trainable_params:,})")
    
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(model.parameters(), lr=LR)
    scaler = torch.cuda.amp.GradScaler(enabled=(device == "cuda"))
    
    history = {
        'train_loss': [], 'val_accuracy': [], 'val_f1_macro': [],
        'val_precision': [], 'val_recall': [], 'combined_metric': []
    }
    
    best_combined_metric = 0.0
    best_val_f1 = 0.0
    best_val_accuracy = 0.0
    best_epoch = 0
    
    for epoch in range(epochs):
        epoch_start = time.time()
        train_loss = train_epoch(model, train_loader, criterion, optimizer, device, scaler)
        val_preds, val_labels = validate(model, val_loader, device)
        
        val_accuracy = accuracy_score(val_labels, val_preds)
        val_f1_macro = f1_score(val_labels, val_preds, average='macro')
        val_precision = precision_score(val_labels, val_preds, average='macro', zero_division=0)
        val_recall = recall_score(val_labels, val_preds, average='macro', zero_division=0)
        combined_metric = (F1_WEIGHT * val_f1_macro) + (ACC_WEIGHT * val_accuracy)
        
        history['train_loss'].append(train_loss)
        history['val_accuracy'].append(val_accuracy)
        history['val_f1_macro'].append(val_f1_macro)
        history['val_precision'].append(val_precision)
        history['val_recall'].append(val_recall)
        history['combined_metric'].append(combined_metric)
        
        epoch_time = time.time() - epoch_start
        monitor.update_peak_memory()
        
        print(f"\nÉpoca {epoch+1}/{epochs} - {epoch_time:.1f}s")
        print(f"  Loss: {train_loss:.4f} | Acc: {val_accuracy:.4f} | F1: {val_f1_macro:.4f} | Combined: {combined_metric:.4f}")
        
        if combined_metric > best_combined_metric:
            best_combined_metric = combined_metric
            best_val_f1 = val_f1_macro
            best_val_accuracy = val_accuracy
            best_epoch = epoch + 1
            
            model_path = os.path.join(MODELS_PATH, f"{model_name}_best.pth")
            torch.save({
                'epoch': epoch + 1,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'val_f1': val_f1_macro,
                'val_accuracy': val_accuracy,
                'combined_metric': combined_metric,
            }, model_path)
            print(f"  ✓ Modelo salvo!")
        
        if early_stopping(combined_metric):
            print(f"\nEARLY STOPPING na época {epoch+1}")
            break
    
    monitor_stats = monitor.end_monitoring()
    
    return {
        'model_name': model_name,
        'history': history,
        'best_combined_metric': best_combined_metric,
        'best_val_f1': best_val_f1,
        'best_val_accuracy': best_val_accuracy,
        'best_epoch': best_epoch,
        'epochs_completed': len(history['train_loss']),
        'total_parameters': total_params,
        'trainable_parameters': trainable_params,
        **monitor_stats
    }

# %%
# AVALIAÇÃO
def evaluate_model(model_name, test_loader, device):
    print(f"\n{'='*80}")
    print(f"AVALIAÇÃO: {model_name.upper()}")
    print(f"{'='*80}")
    
    model = create_model(model_name)
    model_path = os.path.join(MODELS_PATH, f"{model_name}_best.pth")
    
    if not os.path.exists(model_path):
        print(f"❌ Modelo não encontrado")
        return None
    
    checkpoint = torch.load(model_path, map_location=device)
    model.load_state_dict(checkpoint['model_state_dict'])
    model.to(device)
    model.eval()
    
    test_preds, test_labels = validate(model, test_loader, device)
    
    test_accuracy = accuracy_score(test_labels, test_preds)
    test_f1_macro = f1_score(test_labels, test_preds, average='macro')
    test_f1_weighted = f1_score(test_labels, test_preds, average='weighted')
    test_precision = precision_score(test_labels, test_preds, average='macro', zero_division=0)
    test_recall = recall_score(test_labels, test_preds, average='macro', zero_division=0)
    
    class_names = list(EMOTION_LABELS.keys())
    class_report = classification_report(
        test_labels, test_preds,
        target_names=class_names,
        output_dict=True,
        zero_division=0
    )
    
    conf_matrix = confusion_matrix(test_labels, test_preds)
    
    print(f"\n📊 MÉTRICAS:")
    print(f"  Accuracy: {test_accuracy:.4f}")
    print(f"  F1-Macro: {test_f1_macro:.4f}")
    print(f"  F1-Weighted: {test_f1_weighted:.4f}")
    print(f"  Precision: {test_precision:.4f}")
    print(f"  Recall: {test_recall:.4f}")
    
    return {
        'model_name': model_name,
        'test_accuracy': test_accuracy,
        'test_f1_macro': test_f1_macro,
        'test_f1_weighted': test_f1_weighted,
        'test_precision': test_precision,
        'test_recall': test_recall,
        'class_report': class_report,
        'confusion_matrix': conf_matrix.tolist(),
        'y_true': test_labels,
        'y_pred': test_preds,
        'conf_matrix_obj': conf_matrix
    }

# %%
def main():
    """Função principal."""
    print("\n📂 Carregando datasets...")
    
    from torch.utils.data import Subset
    from sklearn.model_selection import train_test_split
    
    train_transform = create_train_transform()
    val_transform = create_val_transform()
    
    # Carregar treino completo
    train_dataset_full = EmotionDataset(
        root_dir=os.path.join(DATASET_PATH, 'train'),
        transform=train_transform
    )
    
    # ← NOVO: Calcular distribuição do treino
    train_distribution = {}
    for label in train_dataset_full.labels:
        train_distribution[label] = train_distribution.get(label, 0) + 1
    
    # Split 80/20
    train_indices, val_indices = train_test_split(
        range(len(train_dataset_full)),
        test_size=0.2,
        stratify=train_dataset_full.labels,
        random_state=42
    )
    
    train_dataset = Subset(train_dataset_full, train_indices)
    
    val_dataset_full = EmotionDataset(
        root_dir=os.path.join(DATASET_PATH, 'train'),
        transform=val_transform
    )
    val_dataset = Subset(val_dataset_full, val_indices)
    
    test_dataset = EmotionDataset(
        root_dir=os.path.join(DATASET_PATH, 'test'),
        transform=val_transform
    )
    
    print(f"✓ Train: {len(train_dataset):,} | Val: {len(val_dataset):,} | Test: {len(test_dataset):,}")
    
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, 
                             num_workers=NUM_WORKERS, pin_memory=True)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, 
                            num_workers=NUM_WORKERS, pin_memory=True)
    test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, 
                            num_workers=NUM_WORKERS, pin_memory=True)
    
    models_to_train = ['resnet50', 'efficientnet_b0', 'vit_b_16']
    all_results = []
    
    for model_name in models_to_train:
        monitor = ResourceMonitor(model_name)
        early_stopping = EarlyStopping(
            patience=EARLY_STOP_PATIENCE, 
            min_delta=EARLY_STOP_MIN_DELTA, 
            mode='max', 
            verbose=True
        )
        
        train_result = train_model(model_name, train_loader, val_loader, DEVICE, 
                                  EPOCHS, early_stopping, monitor)
        
        if train_result:
            eval_result = evaluate_model(model_name, test_loader, DEVICE)
            
            if eval_result:
                combined_result = {**train_result, **eval_result}
                all_results.append(combined_result)
                
                timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
                experiment_id = f"{model_name}_{timestamp}"
                
                metrics_for_viz = {
                    'test_accuracy': eval_result['test_accuracy'],
                    'training_time_seconds': train_result['training_time_seconds'],
                    'peak_memory_mb': train_result['peak_memory_mb'],
                    'total_parameters': train_result['total_parameters']
                }
                
                # ← MODIFICADO: Passar train_distribution
                create_comprehensive_visualizations(
                    history=train_result['history'],
                    conf_matrix=eval_result['conf_matrix_obj'],
                    metrics=metrics_for_viz,
                    class_report=eval_result['class_report'],
                    experiment_id=experiment_id,
                    y_true=eval_result['y_true'],
                    y_pred=eval_result['y_pred'],
                    model_name=model_name,
                    train_distribution=train_distribution
                )
                
                metrics_df = pd.DataFrame([combined_result])
                metrics_df.to_csv(
                    os.path.join(METRICS_PATH, f'metrics_{model_name}_{experiment_id}.csv'),
                    index=False
                )
        
        if DEVICE == "cuda":
            torch.cuda.empty_cache()
            gc.collect()
    
    if all_results:
        comparison_df = pd.DataFrame(all_results)
        comparison_df.to_csv(
            os.path.join(METRICS_PATH, 'comparison_all_models.csv'),
            index=False
        )
        
        print(f"\n{'='*80}")
        print("COMPARAÇÃO FINAL")
        print(f"{'='*80}")
        print(comparison_df[['model_name', 'test_accuracy', 'test_f1_macro', 
                             'best_epoch', 'epochs_completed', 'training_time_seconds',
                             'peak_memory_mb']].to_string(index=False))
        print(f"{'='*80}")
    
    print(f"\n✅ Completo!")
    print(f"📁 {RESULTS_PATH}")

# %%
if __name__ == "__main__":
    try:
        main()
    except KeyboardInterrupt:
        print("\n\n⚠️ Interrompido")
    except Exception as e:
        print(f"\n\n❌ ERRO: {type(e).__name__}")
        print(f"{e}")
        import traceback
        traceback.print_exc()
# Out:
# 📂 Carregando datasets...
# ✓ Train: 137,360 | Val: 34,340 | Test: 17,102
#
# ================================================================================
# TREINANDO: RESNET50
# ================================================================================
#
# 🔍 Iniciando monitoramento: resnet50
#   • Initial RAM: 817.57 MB
#   • Initial GPU: 0.00 MB
# ✓ Modelo 'resnet50' criado
#
# 📊 Parâmetros: 23,516,103 (Treináveis: 23,516,103)
#
# Época 1/100 - 394.3s
#   Loss: 1.4971 | Acc: 0.5906 | F1: 0.5882 | Combined: 0.5891
#   ✓ Modelo salvo!
# Early Stopping: Baseline: 0.5891
#
# Época 2/100 - 397.0s
#   Loss: 1.1303 | Acc: 0.6898 | F1: 0.6837 | Combined: 0.6861
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.6861, Δ=+0.0970)
#
# Época 3/100 - 398.1s
#   Loss: 0.9292 | Acc: 0.7376 | F1: 0.7311 | Combined: 0.7337
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.7337, Δ=+0.0475)
#
# Época 4/100 - 398.2s
#   Loss: 0.8039 | Acc: 0.7736 | F1: 0.7719 | Combined: 0.7726
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.7726, Δ=+0.0389)
#
# Época 5/100 - 398.2s
#   Loss: 0.7157 | Acc: 0.7900 | F1: 0.7849 | Combined: 0.7869
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.7869, Δ=+0.0144)
#
# Época 6/100 - 397.9s
#   Loss: 0.6525 | Acc: 0.8125 | F1: 0.8071 | Combined: 0.8093
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8093, Δ=+0.0224)
#
# Época 7/100 - 399.7s
#   Loss: 0.6052 | Acc: 0.8194 | F1: 0.8121 | Combined: 0.8150
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8150, Δ=+0.0058)
#
# Época 8/100 - 399.0s
#   Loss: 0.5595 | Acc: 0.8302 | F1: 0.8220 | Combined: 0.8253
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8253, Δ=+0.0102)
#
# Época 9/100 - 399.0s
#   Loss: 0.5236 | Acc: 0.8354 | F1: 0.8291 | Combined: 0.8316
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8316, Δ=+0.0064)
#
# Época 10/100 - 395.9s
#   Loss: 0.4987 | Acc: 0.8329 | F1: 0.8225 | Combined: 0.8267
# Early Stopping: Sem melhoria (1/15)
#
# Época 11/100 - 398.8s
#   Loss: 0.4757 | Acc: 0.8408 | F1: 0.8321 | Combined: 0.8356
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8356, Δ=+0.0039)
#
# Época 12/100 - 399.3s
#   Loss: 0.4534 | Acc: 0.8448 | F1: 0.8410 | Combined: 0.8426
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8426, Δ=+0.0070)
#
# Época 13/100 - 397.7s
#   Loss: 0.4322 | Acc: 0.8493 | F1: 0.8443 | Combined: 0.8463
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8463, Δ=+0.0038)
#
# Época 14/100 - 397.5s
#   Loss: 0.4175 | Acc: 0.8547 | F1: 0.8483 | Combined: 0.8509
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8509, Δ=+0.0045)
#
# Época 15/100 - 397.3s
#   Loss: 0.4010 | Acc: 0.8544 | F1: 0.8488 | Combined: 0.8510
#   ✓ Modelo salvo!
# Early Stopping: Sem melhoria (1/15)
#
# Época 16/100 - 398.5s
#   Loss: 0.3885 | Acc: 0.8517 | F1: 0.8438 | Combined: 0.8470
# Early Stopping: Sem melhoria (2/15)
#
# Época 17/100 - 398.0s
#   Loss: 0.3801 | Acc: 0.8585 | F1: 0.8523 | Combined: 0.8548
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8548, Δ=+0.0039)
#
# Época 18/100 - 398.2s
#   Loss: 0.3621 | Acc: 0.8582 | F1: 0.8516 | Combined: 0.8542
# Early Stopping: Sem melhoria (1/15)
#
# Época 19/100 - 397.6s
#   Loss: 0.3546 | Acc: 0.8585 | F1: 0.8524 | Combined: 0.8548
#   ✓ Modelo salvo!
# Early Stopping: Sem melhoria (2/15)
#
# Época 20/100 - 397.9s
#   Loss: 0.3446 | Acc: 0.8551 | F1: 0.8479 | Combined: 0.8507
# Early Stopping: Sem melhoria (3/15)
#
# Época 21/100 - 397.9s
#   Loss: 0.3369 | Acc: 0.8589 | F1: 0.8509 | Combined: 0.8541
# Early Stopping: Sem melhoria (4/15)
#
# Época 22/100 - 397.3s
#   Loss: 0.3256 | Acc: 0.8599 | F1: 0.8531 | Combined: 0.8558
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8558, Δ=+0.0010)
#
# Época 23/100 - 398.0s
#   Loss: 0.3221 | Acc: 0.8561 | F1: 0.8473 | Combined: 0.8508
# Early Stopping: Sem melhoria (1/15)
#
# Época 24/100 - 398.2s
#   Loss: 0.3115 | Acc: 0.8594 | F1: 0.8525 | Combined: 0.8553
# Early Stopping: Sem melhoria (2/15)
#
# Época 25/100 - 398.2s
#   Loss: 0.3076 | Acc: 0.8608 | F1: 0.8543 | Combined: 0.8569
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8569, Δ=+0.0011)
#
# Época 26/100 - 397.4s
#   Loss: 0.3005 | Acc: 0.8660 | F1: 0.8611 | Combined: 0.8631
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8631, Δ=+0.0062)
#
# Época 27/100 - 399.7s
#   Loss: 0.2949 | Acc: 0.8628 | F1: 0.8562 | Combined: 0.8589
# Early Stopping: Sem melhoria (1/15)
#
# Época 28/100 - 399.8s
#   Loss: 0.2878 | Acc: 0.8635 | F1: 0.8574 | Combined: 0.8598
# Early Stopping: Sem melhoria (2/15)
#
# Época 29/100 - 398.3s
#   Loss: 0.2845 | Acc: 0.8664 | F1: 0.8611 | Combined: 0.8632
#   ✓ Modelo salvo!
# Early Stopping: Sem melhoria (3/15)
#
# Época 30/100 - 398.1s
#   Loss: 0.2784 | Acc: 0.8632 | F1: 0.8559 | Combined: 0.8588
# Early Stopping: Sem melhoria (4/15)
#
# Época 31/100 - 397.8s
#   Loss: 0.2747 | Acc: 0.8613 | F1: 0.8547 | Combined: 0.8574
# Early Stopping: Sem melhoria (5/15)
#
# Época 32/100 - 395.8s
#   Loss: 0.2691 | Acc: 0.8628 | F1: 0.8556 | Combined: 0.8585
# Early Stopping: Sem melhoria (6/15)
#
# Época 33/100 - 399.8s
#   Loss: 0.2664 | Acc: 0.8639 | F1: 0.8568 | Combined: 0.8596
# Early Stopping: Sem melhoria (7/15)
#
# Época 34/100 - 399.2s
#   Loss: 0.2607 | Acc: 0.8666 | F1: 0.8604 | Combined: 0.8629
# Early Stopping: Sem melhoria (8/15)
#
# Época 35/100 - 399.6s
#   Loss: 0.2586 | Acc: 0.8639 | F1: 0.8568 | Combined: 0.8597
# Early Stopping: Sem melhoria (9/15)
#
# Época 36/100 - 399.2s
#   Loss: 0.2532 | Acc: 0.8666 | F1: 0.8597 | Combined: 0.8625
# Early Stopping: Sem melhoria (10/15)
#
# Época 37/100 - 399.5s
#   Loss: 0.2532 | Acc: 0.8635 | F1: 0.8569 | Combined: 0.8595
# Early Stopping: Sem melhoria (11/15)
#
# Época 38/100 - 397.5s
#   Loss: 0.2499 | Acc: 0.8637 | F1: 0.8557 | Combined: 0.8589
# Early Stopping: Sem melhoria (12/15)
#
# Época 39/100 - 395.3s
#   Loss: 0.2420 | Acc: 0.8645 | F1: 0.8573 | Combined: 0.8602
# Early Stopping: Sem melhoria (13/15)
#
# Época 40/100 - 394.4s
#   Loss: 0.2421 | Acc: 0.8689 | F1: 0.8634 | Combined: 0.8656
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8656, Δ=+0.0025)
#
# Época 41/100 - 397.4s
#   Loss: 0.2372 | Acc: 0.8655 | F1: 0.8584 | Combined: 0.8613
# Early Stopping: Sem melhoria (1/15)
#
# Época 42/100 - 397.4s
#   Loss: 0.2376 | Acc: 0.8661 | F1: 0.8599 | Combined: 0.8624
# Early Stopping: Sem melhoria (2/15)
#
# Época 43/100 - 398.3s
#   Loss: 0.2346 | Acc: 0.8650 | F1: 0.8588 | Combined: 0.8613
# Early Stopping: Sem melhoria (3/15)
#
# Época 44/100 - 398.0s
#   Loss: 0.2305 | Acc: 0.8659 | F1: 0.8587 | Combined: 0.8616
# Early Stopping: Sem melhoria (4/15)
#
# Época 45/100 - 398.2s
#   Loss: 0.2281 | Acc: 0.8615 | F1: 0.8530 | Combined: 0.8564
# Early Stopping: Sem melhoria (5/15)
#
# Época 46/100 - 397.3s
#   Loss: 0.2252 | Acc: 0.8664 | F1: 0.8584 | Combined: 0.8616
# Early Stopping: Sem melhoria (6/15)
#
# Época 47/100 - 398.8s
#   Loss: 0.2240 | Acc: 0.8654 | F1: 0.8586 | Combined: 0.8613
# Early Stopping: Sem melhoria (7/15)
#
# Época 48/100 - 398.7s
#   Loss: 0.2207 | Acc: 0.8695 | F1: 0.8633 | Combined: 0.8658
#   ✓ Modelo salvo!
# Early Stopping: Sem melhoria (8/15)
#
# Época 49/100 - 397.7s
#   Loss: 0.2184 | Acc: 0.8690 | F1: 0.8628 | Combined: 0.8653
# Early Stopping: Sem melhoria (9/15)
#
# Época 50/100 - 396.8s
#   Loss: 0.2155 | Acc: 0.8665 | F1: 0.8580 | Combined: 0.8614
# Early Stopping: Sem melhoria (10/15)
#
# Época 51/100 - 395.6s
#   Loss: 0.2136 | Acc: 0.8649 | F1: 0.8560 | Combined: 0.8596
# Early Stopping: Sem melhoria (11/15)
#
# Época 52/100 - 395.4s
#   Loss: 0.2123 | Acc: 0.8691 | F1: 0.8631 | Combined: 0.8655
# Early Stopping: Sem melhoria (12/15)
#
# Época 53/100 - 399.5s
#   Loss: 0.2109 | Acc: 0.8691 | F1: 0.8627 | Combined: 0.8653
# Early Stopping: Sem melhoria (13/15)
#
# Época 54/100 - 397.9s
#   Loss: 0.2083 | Acc: 0.8707 | F1: 0.8637 | Combined: 0.8665
#   ✓ Modelo salvo!
# Early Stopping: Sem melhoria (14/15)
#
# Época 55/100 - 398.1s
#   Loss: 0.2077 | Acc: 0.8703 | F1: 0.8641 | Combined: 0.8666
#   ✓ Modelo salvo!
# Early Stopping: Sem melhoria (15/15)
# Early Stopping: ATIVADO após 15 épocas
#
# EARLY STOPPING na época 55
#
# ======================================================================
# MONITORING REPORT: RESNET50
# ======================================================================
# Total training time: 6:04:55
# Initial RAM: 817.57 MB
# Final RAM: 1385.49 MB
# Peak RAM: 1385.49 MB
# Memory increase: 567.91 MB
# Peak GPU Memory: 1757.03 MB
# Final GPU Memory: 375.33 MB
# ======================================================================
#
# ================================================================================
# AVALIAÇÃO: RESNET50
# ================================================================================
# ✓ Modelo 'resnet50' criado
#
# 📊 MÉTRICAS:
#   Accuracy: 0.5574
#   F1-Macro: 0.4110
#   F1-Weighted: 0.5534
#   Precision: 0.4200
#   Recall: 0.4041
# ================================================================================
# TREINANDO: EFFICIENTNET_B0
# ================================================================================
#
# 🔍 Iniciando monitoramento: efficientnet_b0
#   • Initial RAM: 1485.09 MB
#   • Initial GPU: 16.25 MB
# ✓ Modelo 'efficientnet_b0' criado
#
# 📊 Parâmetros: 4,015,939 (Treináveis: 4,015,939)
#
# Época 1/100 - 236.6s
#   Loss: 1.5327 | Acc: 0.5673 | F1: 0.5590 | Combined: 0.5623
#   ✓ Modelo salvo!
# Early Stopping: Baseline: 0.5623
#
# Época 2/100 - 236.8s
#   Loss: 1.2191 | Acc: 0.6492 | F1: 0.6463 | Combined: 0.6475
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.6475, Δ=+0.0851)
#
# Época 3/100 - 236.2s
#   Loss: 1.0411 | Acc: 0.7141 | F1: 0.7134 | Combined: 0.7137
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.7137, Δ=+0.0662)
#
# Época 4/100 - 236.7s
#   Loss: 0.9053 | Acc: 0.7589 | F1: 0.7531 | Combined: 0.7554
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.7554, Δ=+0.0417)
#
# Época 5/100 - 236.5s
#   Loss: 0.8071 | Acc: 0.7812 | F1: 0.7740 | Combined: 0.7769
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.7769, Δ=+0.0215)
#
# Época 6/100 - 236.9s
#   Loss: 0.7342 | Acc: 0.8034 | F1: 0.7976 | Combined: 0.7999
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.7999, Δ=+0.0230)
#
# Época 7/100 - 236.3s
#   Loss: 0.6748 | Acc: 0.8138 | F1: 0.8041 | Combined: 0.8080
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8080, Δ=+0.0080)
#
# Época 8/100 - 236.6s
#   Loss: 0.6290 | Acc: 0.8285 | F1: 0.8237 | Combined: 0.8256
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8256, Δ=+0.0176)
#
# Época 9/100 - 236.9s
#   Loss: 0.5845 | Acc: 0.8385 | F1: 0.8324 | Combined: 0.8349
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8349, Δ=+0.0092)
#
# Época 10/100 - 236.8s
#   Loss: 0.5524 | Acc: 0.8402 | F1: 0.8330 | Combined: 0.8358
#   ✓ Modelo salvo!
# Early Stopping: Sem melhoria (1/15)
#
# Época 11/100 - 236.5s
#   Loss: 0.5258 | Acc: 0.8433 | F1: 0.8329 | Combined: 0.8370
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8370, Δ=+0.0022)
#
# Época 12/100 - 236.9s
#   Loss: 0.5016 | Acc: 0.8475 | F1: 0.8383 | Combined: 0.8420
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8420, Δ=+0.0049)
#
# Época 13/100 - 236.7s
#   Loss: 0.4787 | Acc: 0.8550 | F1: 0.8496 | Combined: 0.8518
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8518, Δ=+0.0098)
#
# Época 14/100 - 236.3s
#   Loss: 0.4578 | Acc: 0.8546 | F1: 0.8494 | Combined: 0.8515
# Early Stopping: Sem melhoria (1/15)
#
# Época 15/100 - 236.1s
#   Loss: 0.4409 | Acc: 0.8578 | F1: 0.8513 | Combined: 0.8539
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8539, Δ=+0.0022)
#
# Época 16/100 - 236.7s
#   Loss: 0.4251 | Acc: 0.8612 | F1: 0.8561 | Combined: 0.8582
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8582, Δ=+0.0042)
#
# Época 17/100 - 237.2s
#   Loss: 0.4109 | Acc: 0.8596 | F1: 0.8517 | Combined: 0.8548
# Early Stopping: Sem melhoria (1/15)
#
# Época 18/100 - 236.7s
#   Loss: 0.3992 | Acc: 0.8649 | F1: 0.8582 | Combined: 0.8609
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8609, Δ=+0.0027)
#
# Época 19/100 - 236.7s
#   Loss: 0.3866 | Acc: 0.8575 | F1: 0.8492 | Combined: 0.8525
# Early Stopping: Sem melhoria (1/15)
#
# Época 20/100 - 236.6s
#   Loss: 0.3710 | Acc: 0.8643 | F1: 0.8566 | Combined: 0.8597
# Early Stopping: Sem melhoria (2/15)
#
# Época 21/100 - 236.8s
#   Loss: 0.3670 | Acc: 0.8648 | F1: 0.8577 | Combined: 0.8606
# Early Stopping: Sem melhoria (3/15)
#
# Época 22/100 - 237.0s
#   Loss: 0.3579 | Acc: 0.8644 | F1: 0.8568 | Combined: 0.8598
# Early Stopping: Sem melhoria (4/15)
#
# Época 23/100 - 236.9s
#   Loss: 0.3480 | Acc: 0.8628 | F1: 0.8539 | Combined: 0.8575
# Early Stopping: Sem melhoria (5/15)
#
# Época 24/100 - 236.9s
#   Loss: 0.3387 | Acc: 0.8699 | F1: 0.8638 | Combined: 0.8663
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8663, Δ=+0.0054)
#
# Época 25/100 - 236.7s
#   Loss: 0.3285 | Acc: 0.8676 | F1: 0.8605 | Combined: 0.8633
# Early Stopping: Sem melhoria (1/15)
#
# Época 26/100 - 236.9s
#   Loss: 0.3253 | Acc: 0.8635 | F1: 0.8553 | Combined: 0.8586
# Early Stopping: Sem melhoria (2/15)
#
# Época 27/100 - 237.0s
#   Loss: 0.3173 | Acc: 0.8695 | F1: 0.8628 | Combined: 0.8655
# Early Stopping: Sem melhoria (3/15)
#
# Época 28/100 - 236.9s
#   Loss: 0.3127 | Acc: 0.8679 | F1: 0.8605 | Combined: 0.8635
# Early Stopping: Sem melhoria (4/15)
#
# Época 29/100 - 236.1s
#   Loss: 0.3065 | Acc: 0.8705 | F1: 0.8635 | Combined: 0.8663
#   ✓ Modelo salvo!
# Early Stopping: Sem melhoria (5/15)
#
# Época 30/100 - 236.6s
#   Loss: 0.3008 | Acc: 0.8650 | F1: 0.8575 | Combined: 0.8605
# Early Stopping: Sem melhoria (6/15)
#
# Época 31/100 - 236.9s
#   Loss: 0.2970 | Acc: 0.8655 | F1: 0.8576 | Combined: 0.8607
# Early Stopping: Sem melhoria (7/15)
#
# Época 32/100 - 236.8s
#   Loss: 0.2919 | Acc: 0.8711 | F1: 0.8643 | Combined: 0.8670
#   ✓ Modelo salvo!
# Early Stopping: Sem melhoria (8/15)
#
# Época 33/100 - 236.8s
#   Loss: 0.2893 | Acc: 0.8671 | F1: 0.8588 | Combined: 0.8621
# Early Stopping: Sem melhoria (9/15)
#
# Época 34/100 - 236.4s
#   Loss: 0.2825 | Acc: 0.8686 | F1: 0.8606 | Combined: 0.8638
# Early Stopping: Sem melhoria (10/15)
#
# Época 35/100 - 236.7s
#   Loss: 0.2812 | Acc: 0.8674 | F1: 0.8599 | Combined: 0.8629
# Early Stopping: Sem melhoria (11/15)
#
# Época 36/100 - 237.0s
#   Loss: 0.2783 | Acc: 0.8679 | F1: 0.8603 | Combined: 0.8633
# Early Stopping: Sem melhoria (12/15)
#
# Época 37/100 - 236.5s
#   Loss: 0.2716 | Acc: 0.8674 | F1: 0.8591 | Combined: 0.8624
# Early Stopping: Sem melhoria (13/15)
#
# Época 38/100 - 236.5s
#   Loss: 0.2673 | Acc: 0.8707 | F1: 0.8640 | Combined: 0.8667
# Early Stopping: Sem melhoria (14/15)
#
# Época 39/100 - 236.7s
#   Loss: 0.2674 | Acc: 0.8729 | F1: 0.8665 | Combined: 0.8691
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8691, Δ=+0.0028)
#
# Época 40/100 - 236.6s
#   Loss: 0.2594 | Acc: 0.8688 | F1: 0.8621 | Combined: 0.8648
# Early Stopping: Sem melhoria (1/15)
#
# Época 41/100 - 236.6s
#   Loss: 0.2576 | Acc: 0.8691 | F1: 0.8621 | Combined: 0.8649
# Early Stopping: Sem melhoria (2/15)
#
# Época 42/100 - 236.7s
#   Loss: 0.2567 | Acc: 0.8742 | F1: 0.8682 | Combined: 0.8706
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8706, Δ=+0.0016)
#
# Época 43/100 - 236.7s
#   Loss: 0.2546 | Acc: 0.8736 | F1: 0.8673 | Combined: 0.8698
# Early Stopping: Sem melhoria (1/15)
#
# Época 44/100 - 236.8s
#   Loss: 0.2479 | Acc: 0.8693 | F1: 0.8614 | Combined: 0.8645
# Early Stopping: Sem melhoria (2/15)
#
# Época 45/100 - 236.7s
#   Loss: 0.2497 | Acc: 0.8693 | F1: 0.8621 | Combined: 0.8650
# Early Stopping: Sem melhoria (3/15)
#
# Época 46/100 - 236.7s
#   Loss: 0.2460 | Acc: 0.8728 | F1: 0.8662 | Combined: 0.8688
# Early Stopping: Sem melhoria (4/15)
#
# Época 47/100 - 235.4s
#   Loss: 0.2441 | Acc: 0.8701 | F1: 0.8627 | Combined: 0.8657
# Early Stopping: Sem melhoria (5/15)
#
# Época 48/100 - 236.5s
#   Loss: 0.2411 | Acc: 0.8709 | F1: 0.8639 | Combined: 0.8667
# Early Stopping: Sem melhoria (6/15)
#
# Época 49/100 - 236.8s
#   Loss: 0.2376 | Acc: 0.8696 | F1: 0.8626 | Combined: 0.8654
# Early Stopping: Sem melhoria (7/15)
#
# Época 50/100 - 237.0s
#   Loss: 0.2365 | Acc: 0.8743 | F1: 0.8683 | Combined: 0.8707
#   ✓ Modelo salvo!
# Early Stopping: Sem melhoria (8/15)
#
# Época 51/100 - 236.7s
#   Loss: 0.2336 | Acc: 0.8709 | F1: 0.8632 | Combined: 0.8662
# Early Stopping: Sem melhoria (9/15)
#
# Época 52/100 - 237.5s
#   Loss: 0.2345 | Acc: 0.8718 | F1: 0.8645 | Combined: 0.8674
# Early Stopping: Sem melhoria (10/15)
#
# Época 53/100 - 236.7s
#   Loss: 0.2301 | Acc: 0.8710 | F1: 0.8639 | Combined: 0.8667
# Early Stopping: Sem melhoria (11/15)
#
# Época 54/100 - 236.4s
#   Loss: 0.2286 | Acc: 0.8706 | F1: 0.8637 | Combined: 0.8665
# Early Stopping: Sem melhoria (12/15)
#
# Época 55/100 - 235.2s
#   Loss: 0.2284 | Acc: 0.8698 | F1: 0.8624 | Combined: 0.8653
# Early Stopping: Sem melhoria (13/15)
#
# Época 56/100 - 237.4s
#   Loss: 0.2260 | Acc: 0.8703 | F1: 0.8635 | Combined: 0.8662
# Early Stopping: Sem melhoria (14/15)
#
# Época 57/100 - 237.0s
#   Loss: 0.2240 | Acc: 0.8737 | F1: 0.8669 | Combined: 0.8696
# Early Stopping: Sem melhoria (15/15)
# Early Stopping: ATIVADO após 15 épocas
#
# EARLY STOPPING na época 57
#
# ======================================================================
# MONITORING REPORT: EFFICIENTNET_B0
# ======================================================================
# Total training time: 3:44:52
# Initial RAM: 1485.09 MB
# Final RAM: 1540.95 MB
# Peak RAM: 1540.96 MB
# Memory increase: 55.86 MB
# Peak GPU Memory: 1757.03 MB
# Final GPU Memory: 77.87 MB
# ======================================================================
#
# ================================================================================
# AVALIAÇÃO: EFFICIENTNET_B0
# ================================================================================
# ✓ Modelo 'efficientnet_b0' criado
#
# 📊 MÉTRICAS:
#   Accuracy: 0.5586
#   F1-Macro: 0.4137
#   F1-Weighted: 0.5540
#   Precision: 0.4226
#   Recall: 0.4067
# ================================================================================
# TREINANDO: VIT_B_16
# ================================================================================
#
# 🔍 Iniciando monitoramento: vit_b_16
#   • Initial RAM: 1547.04 MB
#   • Initial GPU: 16.25 MB
# ✓ Modelo 'vit_b_16' criado
#
# 📊 Parâmetros: 85,410,823 (Treináveis: 85,410,823)
#
# Época 1/100 - 955.2s
#   Loss: 1.9172 | Acc: 0.2473 | F1: 0.2121 | Combined: 0.2262
#   ✓ Modelo salvo!
# Early Stopping: Baseline: 0.2262
#
# Época 2/100 - 952.8s
#   Loss: 1.7871 | Acc: 0.3390 | F1: 0.3127 | Combined: 0.3232
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.3232, Δ=+0.0970)
#
# Época 3/100 - 953.3s
#   Loss: 1.6581 | Acc: 0.4183 | F1: 0.4007 | Combined: 0.4078
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.4078, Δ=+0.0846)
#
# Época 4/100 - 955.2s
#   Loss: 1.5327 | Acc: 0.5011 | F1: 0.4942 | Combined: 0.4970
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.4970, Δ=+0.0892)
#
# Época 5/100 - 957.1s
#   Loss: 1.4165 | Acc: 0.5403 | F1: 0.5272 | Combined: 0.5325
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.5325, Δ=+0.0355)
#
# Época 6/100 - 956.5s
#   Loss: 1.3226 | Acc: 0.5791 | F1: 0.5711 | Combined: 0.5743
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.5743, Δ=+0.0418)
#
# Época 7/100 - 955.6s
#   Loss: 1.2262 | Acc: 0.6324 | F1: 0.6227 | Combined: 0.6266
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.6266, Δ=+0.0523)
#
# Época 8/100 - 953.1s
#   Loss: 1.1378 | Acc: 0.6679 | F1: 0.6597 | Combined: 0.6630
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.6630, Δ=+0.0365)
#
# Época 9/100 - 956.7s
#   Loss: 1.0566 | Acc: 0.7007 | F1: 0.6936 | Combined: 0.6964
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.6964, Δ=+0.0334)
#
# Época 10/100 - 954.9s
#   Loss: 0.9840 | Acc: 0.7289 | F1: 0.7209 | Combined: 0.7241
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.7241, Δ=+0.0277)
#
# Época 11/100 - 954.0s
#   Loss: 0.9271 | Acc: 0.7358 | F1: 0.7325 | Combined: 0.7338
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.7338, Δ=+0.0097)
#
# Época 12/100 - 958.6s
#   Loss: 0.8771 | Acc: 0.7563 | F1: 0.7521 | Combined: 0.7538
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.7538, Δ=+0.0200)
#
# Época 13/100 - 957.0s
#   Loss: 0.8300 | Acc: 0.7626 | F1: 0.7544 | Combined: 0.7577
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.7577, Δ=+0.0039)
#
# Época 14/100 - 953.1s
#   Loss: 0.7907 | Acc: 0.7800 | F1: 0.7733 | Combined: 0.7760
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.7760, Δ=+0.0183)
#
# Época 15/100 - 955.0s
#   Loss: 0.7564 | Acc: 0.7788 | F1: 0.7743 | Combined: 0.7761
#   ✓ Modelo salvo!
# Early Stopping: Sem melhoria (1/15)
#
# Época 16/100 - 955.8s
#   Loss: 0.7271 | Acc: 0.7990 | F1: 0.7882 | Combined: 0.7925
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.7925, Δ=+0.0165)
#
# Época 17/100 - 934.7s
#   Loss: 0.7019 | Acc: 0.8035 | F1: 0.7958 | Combined: 0.7989
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.7989, Δ=+0.0064)
#
# Época 18/100 - 942.5s
#   Loss: 0.6753 | Acc: 0.8105 | F1: 0.8047 | Combined: 0.8070
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8070, Δ=+0.0082)
#
# Época 19/100 - 954.7s
#   Loss: 0.6490 | Acc: 0.8059 | F1: 0.7942 | Combined: 0.7989
# Early Stopping: Sem melhoria (1/15)
#
# Época 20/100 - 954.9s
#   Loss: 0.6259 | Acc: 0.8220 | F1: 0.8137 | Combined: 0.8170
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8170, Δ=+0.0100)
#
# Época 21/100 - 954.3s
#   Loss: 0.6092 | Acc: 0.8191 | F1: 0.8109 | Combined: 0.8142
# Early Stopping: Sem melhoria (1/15)
#
# Época 22/100 - 953.1s
#   Loss: 0.5919 | Acc: 0.8247 | F1: 0.8150 | Combined: 0.8189
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8189, Δ=+0.0018)
#
# Época 23/100 - 952.0s
#   Loss: 0.5731 | Acc: 0.8259 | F1: 0.8171 | Combined: 0.8207
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8207, Δ=+0.0018)
#
# Época 24/100 - 954.6s
#   Loss: 0.5603 | Acc: 0.8334 | F1: 0.8266 | Combined: 0.8293
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8293, Δ=+0.0087)
#
# Época 25/100 - 954.1s
#   Loss: 0.5444 | Acc: 0.8326 | F1: 0.8263 | Combined: 0.8288
# Early Stopping: Sem melhoria (1/15)
#
# Época 26/100 - 954.3s
#   Loss: 0.5295 | Acc: 0.8349 | F1: 0.8288 | Combined: 0.8312
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8312, Δ=+0.0019)
#
# Época 27/100 - 956.3s
#   Loss: 0.5151 | Acc: 0.8345 | F1: 0.8278 | Combined: 0.8305
# Early Stopping: Sem melhoria (1/15)
#
# Época 28/100 - 953.5s
#   Loss: 0.5029 | Acc: 0.8367 | F1: 0.8285 | Combined: 0.8318
#   ✓ Modelo salvo!
# Early Stopping: Sem melhoria (2/15)
#
# Época 29/100 - 954.0s
#   Loss: 0.4914 | Acc: 0.8397 | F1: 0.8353 | Combined: 0.8371
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8371, Δ=+0.0058)
#
# Época 30/100 - 954.5s
#   Loss: 0.4807 | Acc: 0.8387 | F1: 0.8322 | Combined: 0.8348
# Early Stopping: Sem melhoria (1/15)
#
# Época 31/100 - 952.5s
#   Loss: 0.4694 | Acc: 0.8423 | F1: 0.8361 | Combined: 0.8386
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8386, Δ=+0.0015)
#
# Época 32/100 - 946.3s
#   Loss: 0.4615 | Acc: 0.8448 | F1: 0.8384 | Combined: 0.8409
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8409, Δ=+0.0023)
#
# Época 33/100 - 919.1s
#   Loss: 0.4498 | Acc: 0.8400 | F1: 0.8326 | Combined: 0.8356
# Early Stopping: Sem melhoria (1/15)
#
# Época 34/100 - 919.1s
#   Loss: 0.4411 | Acc: 0.8422 | F1: 0.8370 | Combined: 0.8391
# Early Stopping: Sem melhoria (2/15)
#
# Época 35/100 - 919.1s
#   Loss: 0.4319 | Acc: 0.8390 | F1: 0.8318 | Combined: 0.8347
# Early Stopping: Sem melhoria (3/15)
#
# Época 36/100 - 924.6s
#   Loss: 0.4250 | Acc: 0.8462 | F1: 0.8392 | Combined: 0.8420
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8420, Δ=+0.0011)
#
# Época 37/100 - 955.3s
#   Loss: 0.4156 | Acc: 0.8475 | F1: 0.8411 | Combined: 0.8437
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8437, Δ=+0.0017)
#
# Época 38/100 - 941.9s
#   Loss: 0.4071 | Acc: 0.8419 | F1: 0.8353 | Combined: 0.8379
# Early Stopping: Sem melhoria (1/15)
#
# Época 39/100 - 949.3s
#   Loss: 0.4013 | Acc: 0.8493 | F1: 0.8418 | Combined: 0.8448
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8448, Δ=+0.0011)
#
# Época 40/100 - 955.5s
#   Loss: 0.3915 | Acc: 0.8502 | F1: 0.8454 | Combined: 0.8473
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8473, Δ=+0.0025)
#
# Época 41/100 - 954.9s
#   Loss: 0.3853 | Acc: 0.8479 | F1: 0.8415 | Combined: 0.8441
# Early Stopping: Sem melhoria (1/15)
#
# Época 42/100 - 955.2s
#   Loss: 0.3762 | Acc: 0.8485 | F1: 0.8425 | Combined: 0.8449
# Early Stopping: Sem melhoria (2/15)
#
# Época 43/100 - 953.7s
#   Loss: 0.3696 | Acc: 0.8472 | F1: 0.8403 | Combined: 0.8430
# Early Stopping: Sem melhoria (3/15)
#
# Época 44/100 - 958.7s
#   Loss: 0.3608 | Acc: 0.8462 | F1: 0.8374 | Combined: 0.8409
# Early Stopping: Sem melhoria (4/15)
#
# Época 45/100 - 952.9s
#   Loss: 0.3592 | Acc: 0.8492 | F1: 0.8419 | Combined: 0.8448
# Early Stopping: Sem melhoria (5/15)
#
# Época 46/100 - 954.9s
#   Loss: 0.3491 | Acc: 0.8531 | F1: 0.8453 | Combined: 0.8484
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8484, Δ=+0.0011)
#
# Época 47/100 - 955.4s
#   Loss: 0.3431 | Acc: 0.8507 | F1: 0.8436 | Combined: 0.8465
# Early Stopping: Sem melhoria (1/15)
#
# Época 48/100 - 955.0s
#   Loss: 0.3393 | Acc: 0.8520 | F1: 0.8463 | Combined: 0.8486
#   ✓ Modelo salvo!
# Early Stopping: Sem melhoria (2/15)
#
# Época 49/100 - 954.7s
#   Loss: 0.3314 | Acc: 0.8561 | F1: 0.8516 | Combined: 0.8534
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8534, Δ=+0.0050)
#
# Época 50/100 - 952.1s
#   Loss: 0.3228 | Acc: 0.8517 | F1: 0.8431 | Combined: 0.8465
# Early Stopping: Sem melhoria (1/15)
#
# Época 51/100 - 951.9s
#   Loss: 0.3189 | Acc: 0.8553 | F1: 0.8481 | Combined: 0.8510
# Early Stopping: Sem melhoria (2/15)
#
# Época 52/100 - 949.7s
#   Loss: 0.3111 | Acc: 0.8556 | F1: 0.8494 | Combined: 0.8519
# Early Stopping: Sem melhoria (3/15)
#
# Época 53/100 - 949.0s
#   Loss: 0.3062 | Acc: 0.8536 | F1: 0.8475 | Combined: 0.8499
# Early Stopping: Sem melhoria (4/15)
#
# Época 54/100 - 953.6s
#   Loss: 0.3032 | Acc: 0.8501 | F1: 0.8417 | Combined: 0.8451
# Early Stopping: Sem melhoria (5/15)
#
# Época 55/100 - 955.0s
#   Loss: 0.2982 | Acc: 0.8526 | F1: 0.8462 | Combined: 0.8488
# Early Stopping: Sem melhoria (6/15)
#
# Época 56/100 - 954.9s
#   Loss: 0.2935 | Acc: 0.8559 | F1: 0.8492 | Combined: 0.8519
# Early Stopping: Sem melhoria (7/15)
#
# Época 57/100 - 954.8s
#   Loss: 0.2872 | Acc: 0.8564 | F1: 0.8499 | Combined: 0.8525
# Early Stopping: Sem melhoria (8/15)
#
# Época 58/100 - 954.8s
#   Loss: 0.2816 | Acc: 0.8567 | F1: 0.8500 | Combined: 0.8527
# Early Stopping: Sem melhoria (9/15)
#
# Época 59/100 - 953.6s
#   Loss: 0.2774 | Acc: 0.8576 | F1: 0.8509 | Combined: 0.8536
#   ✓ Modelo salvo!
# Early Stopping: Sem melhoria (10/15)
#
# Época 60/100 - 954.2s
#   Loss: 0.2746 | Acc: 0.8561 | F1: 0.8489 | Combined: 0.8518
# Early Stopping: Sem melhoria (11/15)
#
# Época 61/100 - 957.7s
#   Loss: 0.2693 | Acc: 0.8608 | F1: 0.8557 | Combined: 0.8578
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8578, Δ=+0.0043)
#
# Época 62/100 - 956.0s
#   Loss: 0.2670 | Acc: 0.8600 | F1: 0.8524 | Combined: 0.8554
# Early Stopping: Sem melhoria (1/15)
#
# Época 63/100 - 953.9s
#   Loss: 0.2624 | Acc: 0.8539 | F1: 0.8454 | Combined: 0.8488
# Early Stopping: Sem melhoria (2/15)
#
# Época 64/100 - 953.4s
#   Loss: 0.2603 | Acc: 0.8564 | F1: 0.8483 | Combined: 0.8516
# Early Stopping: Sem melhoria (3/15)
#
# Época 65/100 - 959.3s
#   Loss: 0.2543 | Acc: 0.8573 | F1: 0.8500 | Combined: 0.8529
# Early Stopping: Sem melhoria (4/15)
#
# Época 66/100 - 954.6s
#   Loss: 0.2517 | Acc: 0.8600 | F1: 0.8528 | Combined: 0.8557
# Early Stopping: Sem melhoria (5/15)
#
# Época 67/100 - 954.4s
#   Loss: 0.2487 | Acc: 0.8628 | F1: 0.8564 | Combined: 0.8589
#   ✓ Modelo salvo!
# Early Stopping: Melhoria! (0.8589, Δ=+0.0012)
#
# Época 68/100 - 954.2s
#   Loss: 0.2430 | Acc: 0.8575 | F1: 0.8502 | Combined: 0.8531
# Early Stopping: Sem melhoria (1/15)
#
# Época 69/100 - 955.4s
#   Loss: 0.2407 | Acc: 0.8579 | F1: 0.8501 | Combined: 0.8532
# Early Stopping: Sem melhoria (2/15)
#
# Época 70/100 - 955.9s
#   Loss: 0.2386 | Acc: 0.8568 | F1: 0.8485 | Combined: 0.8518
# Early Stopping: Sem melhoria (3/15)
#
# Época 71/100 - 951.0s
#   Loss: 0.2334 | Acc: 0.8577 | F1: 0.8517 | Combined: 0.8541
# Early Stopping: Sem melhoria (4/15)
#
# Época 72/100 - 953.0s
#   Loss: 0.2300 | Acc: 0.8588 | F1: 0.8527 | Combined: 0.8551
# Early Stopping: Sem melhoria (5/15)
#
# Época 73/100 - 957.0s
#   Loss: 0.2303 | Acc: 0.8569 | F1: 0.8490 | Combined: 0.8522
# Early Stopping: Sem melhoria (6/15)
#
# Época 74/100 - 951.1s
#   Loss: 0.2244 | Acc: 0.8589 | F1: 0.8517 | Combined: 0.8546
# Early Stopping: Sem melhoria (7/15)
#
# Época 75/100 - 953.7s
#   Loss: 0.2236 | Acc: 0.8592 | F1: 0.8530 | Combined: 0.8555
# Early Stopping: Sem melhoria (8/15)
#
# Época 76/100 - 954.8s
#   Loss: 0.2206 | Acc: 0.8546 | F1: 0.8459 | Combined: 0.8494
# Early Stopping: Sem melhoria (9/15)
#
# Época 77/100 - 950.5s
#   Loss: 0.2210 | Acc: 0.8618 | F1: 0.8547 | Combined: 0.8576
# Early Stopping: Sem melhoria (10/15)
#
# Época 78/100 - 949.3s
#   Loss: 0.2171 | Acc: 0.8613 | F1: 0.8552 | Combined: 0.8576
# Early Stopping: Sem melhoria (11/15)
#
# Época 79/100 - 948.3s
#   Loss: 0.2136 | Acc: 0.8596 | F1: 0.8511 | Combined: 0.8545
# Early Stopping: Sem melhoria (12/15)
#
# Época 80/100 - 948.0s
#   Loss: 0.2112 | Acc: 0.8593 | F1: 0.8511 | Combined: 0.8543
# Early Stopping: Sem melhoria (13/15)
#
# Época 81/100 - 954.5s
#   Loss: 0.2094 | Acc: 0.8618 | F1: 0.8541 | Combined: 0.8572
# Early Stopping: Sem melhoria (14/15)
#
# Época 82/100 - 955.4s
#   Loss: 0.2073 | Acc: 0.8630 | F1: 0.8575 | Combined: 0.8597
#   ✓ Modelo salvo!
# Early Stopping: Sem melhoria (15/15)
# Early Stopping: ATIVADO após 15 épocas
#
# EARLY STOPPING na época 82
#
# ======================================================================
# MONITORING REPORT: VIT_B_16
# ======================================================================
# Total training time: 21:41:49
# Initial RAM: 1547.04 MB
# Final RAM: 1489.10 MB
# Peak RAM: 1547.04 MB
# Memory increase: -57.94 MB
# Peak GPU Memory: 3675.71 MB
# Final GPU Memory: 1319.52 MB
# ======================================================================
#
# ================================================================================
# AVALIAÇÃO: VIT_B_16
# ================================================================================
# ✓ Modelo 'vit_b_16' criado
#
# 📊 MÉTRICAS:
#   Accuracy: 0.5389
#   F1-Macro: 0.3823
#   F1-Weighted: 0.5320
#   Precision: 0.3979
#   Recall: 0.3725
# ================================================================================
# COMPARAÇÃO FINAL
# ================================================================================
#      model_name  test_accuracy  test_f1_macro  best_epoch  epochs_completed  training_time_seconds  peak_memory_mb
#        resnet50       0.557420       0.410972          55                55           21895.795276     1385.492188
# efficientnet_b0       0.558590       0.413696          50                57           13492.999418     1540.964844
#        vit_b_16       0.538943       0.382290          82                82           78109.693788     1547.035156
# ================================================================================
#
# ✅ Completo!
# 📁 ../results/augmented_online/EXPW
